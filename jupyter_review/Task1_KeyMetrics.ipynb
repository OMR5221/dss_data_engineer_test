# %%
import pandas as pd

# Import key_metrics.json file:
km_df = pd.read_json('key_metrics.json', orient='columns')

km_df.head(10)
# Out:
#             status  waitSeconds  \
# data          done        0.891
# elements      done        0.891
# metrics       done        0.891
# period        done        0.891
# reportSuite   done        0.891
# segment_id    done        0.891
# totals        done        0.891
# type          done        0.891
#
#                                                         report  \
# data         [{'counts': ['0', '0', '0', 'INF'], 'year': 20...
# elements                  [{'id': 'datetime', 'name': 'Date'}]
# metrics      [{'current': False, 'latency': 0, 'type': 'num...
# period                   Sun.  1 Jan. 2012 - Tue. 31 Dec. 2013
# reportSuite  {'id': 'cbsidownloadcomsite', 'name': 'Downloa...
# segment_id
# totals       [3133846597, 1133217487, 1057622162, 153.85875...
# type                                                  overtime
#
#                                        statusMsg  runSeconds
# data         Your report has finished generating      71.144
# elements     Your report has finished generating      71.144
# metrics      Your report has finished generating      71.144
# period       Your report has finished generating      71.144
# reportSuite  Your report has finished generating      71.144
# segment_id   Your report has finished generating      71.144
# totals       Your report has finished generating      71.144
# type         Your report has finished generating      71.144

# %%
import dask.dataframe as dd
import dask.bag as db
import json

km_dd = db.read_text('key_metrics.json').map(json.loads)
data = km_dd.pluck('data')
print(data)
# Out:
# dask.bag<pluck-a..., npartitions=1>

# %%
# list of dicts for report column - data row
km_rd = km_df['report']['data']

km_rd
# Out:
# [{'counts': ['0', '0', '0', 'INF'],
#   'year': 2012,
#   'name': 'Sun.  1 Jan. 2012',
#   'day': 1,
#   'month': 1},
#  {'counts': ['0', '0', '0', 'INF'],
#   'year': 2012,
#   'name': 'Mon.  2 Jan. 2012',
#   'day': 2,
#   'month': 1},
#  {'counts': ['0', '0', '0', 'INF'],
#   'year': 2012,
#   'name': 'Tue.  3 Jan. 2012',
#   'day': 3,
#   'month': 1},
#  {'counts': ['0', '0', '0', 'INF'],
#   'year': 2012,
#   'name': 'Wed.  4 Jan. 2012',
#   'day': 4,
#   'month': 1},
#  {'counts': ['0', '0', '0', 'INF'],
#   'year': 2012,
#   'name': 'Thu.  5 Jan. 2012',
#   'day': 5,
#   'month': 1},
#  {'counts': ['0', '0', '0', 'INF'],
#   'year': 2012,
#   'name': 'Fri.  6 Jan. 2012',
#   'day': 6,
#   'month': 1},
#  {'counts': ['0', '0', '0', 'INF'],
#   'year': 2012,
#   'name': 'Sat.  7 Jan. 2012',
#   'day': 7,
#   'month': 1},
#  {'counts': ['0', '0', '0', 'INF'],
#   'year': 2012,
#   'name': 'Sun.  8 Jan. 2012',
#   'day': 8,
#   'month': 1},
#  {'counts': ['0', '0', '0', 'INF'],
#   'year': 2012,
#   'name': 'Mon.  9 Jan. 2012',
#   'day': 9,
#   'month': 1},
#  {'counts': ['0', '0', '0', 'INF'],
#   'year': 2012,
#   'name': 'Tue. 10 Jan. 2012',
#   'day': 10,
#   'month': 1},
#  {'counts': ['0', '0', '0', 'INF'],
#   'year': 2012,
#   'name': 'Wed. 11 Jan. 2012',
#   'day': 11,
#   'month': 1},
#  {'counts': ['0', '0', '0', 'INF'],
#   'year': 2012,
#   'name': 'Thu. 12 Jan. 2012',
#   'day': 12,
#   'month': 1},
#  {'counts': ['0', '0', '0', 'INF'],
#   'year': 2012,
#   'name': 'Fri. 13 Jan. 2012',
#   'day': 13,
#   'month': 1},
#  {'counts': ['0', '0', '0', 'INF'],
#   'year': 2012,
#   'name': 'Sat. 14 Jan. 2012',
#   'day': 14,
#   'month': 1},
#  {'counts': ['0', '0', '0', 'INF'],
#   'year': 2012,
#   'name': 'Sun. 15 Jan. 2012',
#   'day': 15,
#   'month': 1},
#  {'counts': ['0', '0', '0', 'INF'],
#   'year': 2012,
#   'name': 'Mon. 16 Jan. 2012',
#   'day': 16,
#   'month': 1},
#  {'counts': ['0', '0', '0', 'INF'],
#   'year': 2012,
#   'name': 'Tue. 17 Jan. 2012',
#   'day': 17,
#   'month': 1},
#  {'counts': ['0', '0', '0', 'INF'],
#   'year': 2012,
#   'name': 'Wed. 18 Jan. 2012',
#   'day': 18,
#   'month': 1},
#  {'counts': ['0', '0', '0', 'INF'],
#   'year': 2012,
#   'name': 'Thu. 19 Jan. 2012',
#   'day': 19,
#   'month': 1},
#  {'counts': ['0', '0', '0', 'INF'],
#   'year': 2012,
#   'name': 'Fri. 20 Jan. 2012',
#   'day': 20,
#   'month': 1},
#  {'counts': ['0', '0', '0', 'INF'],
#   'year': 2012,
#   'name': 'Sat. 21 Jan. 2012',
#   'day': 21,
#   'month': 1},
#  {'counts': ['0', '0', '0', 'INF'],
#   'year': 2012,
#   'name': 'Sun. 22 Jan. 2012',
#   'day': 22,
#   'month': 1},
#  {'counts': ['0', '0', '0', 'INF'],
#   'year': 2012,
#   'name': 'Mon. 23 Jan. 2012',
#   'day': 23,
#   'month': 1},
#  {'counts': ['0', '0', '0', 'INF'],
#   'year': 2012,
#   'name': 'Tue. 24 Jan. 2012',
#   'day': 24,
#   'month': 1},
#  {'counts': ['0', '0', '0', 'INF'],
#   'year': 2012,
#   'name': 'Wed. 25 Jan. 2012',
#   'day': 25,
#   'month': 1},
#  {'counts': ['0', '0', '0', 'INF'],
#   'year': 2012,
#   'name': 'Thu. 26 Jan. 2012',
#   'day': 26,
#   'month': 1},
#  {'counts': ['0', '0', '0', 'INF'],
#   'year': 2012,
#   'name': 'Fri. 27 Jan. 2012',
#   'day': 27,
#   'month': 1},
#  {'counts': ['0', '0', '0', 'INF'],
#   'year': 2012,
#   'name': 'Sat. 28 Jan. 2012',
#   'day': 28,
#   'month': 1},
#  {'counts': ['0', '0', '0', 'INF'],
#   'year': 2012,
#   'name': 'Sun. 29 Jan. 2012',
#   'day': 29,
#   'month': 1},
#  {'counts': ['0', '0', '0', 'INF'],
#   'year': 2012,
#   'name': 'Mon. 30 Jan. 2012',
#   'day': 30,
#   'month': 1},
#  {'counts': ['0', '0', '0', 'INF'],
#   'year': 2012,
#   'name': 'Tue. 31 Jan. 2012',
#   'day': 31,
#   'month': 1},
#  {'counts': ['0', '0', '0', 'INF'],
#   'year': 2012,
#   'name': 'Wed.  1 Feb. 2012',
#   'day': 1,
#   'month': 2},
#  {'counts': ['0', '0', '0', 'INF'],
#   'year': 2012,
#   'name': 'Thu.  2 Feb. 2012',
#   'day': 2,
#   'month': 2},
#  {'counts': ['0', '0', '0', 'INF'],
#   'year': 2012,
#   'name': 'Fri.  3 Feb. 2012',
#   'day': 3,
#   'month': 2},
#  {'counts': ['0', '0', '0', 'INF'],
#   'year': 2012,
#   'name': 'Sat.  4 Feb. 2012',
#   'day': 4,
#   'month': 2},
#  {'counts': ['0', '0', '0', 'INF'],
#   'year': 2012,
#   'name': 'Sun.  5 Feb. 2012',
#   'day': 5,
#   'month': 2},
#  {'counts': ['0', '0', '0', 'INF'],
#   'year': 2012,
#   'name': 'Mon.  6 Feb. 2012',
#   'day': 6,
#   'month': 2},
#  {'counts': ['0', '0', '0', 'INF'],
#   'year': 2012,
#   'name': 'Tue.  7 Feb. 2012',
#   'day': 7,
#   'month': 2},
#  {'counts': ['0', '0', '0', 'INF'],
#   'year': 2012,
#   'name': 'Wed.  8 Feb. 2012',
#   'day': 8,
#   'month': 2},
#  {'counts': ['0', '0', '0', 'INF'],
#   'year': 2012,
#   'name': 'Thu.  9 Feb. 2012',
#   'day': 9,
#   'month': 2},
#  {'counts': ['0', '0', '0', 'INF'],
#   'year': 2012,
#   'name': 'Fri. 10 Feb. 2012',
#   'day': 10,
#   'month': 2},
#  {'counts': ['0', '0', '0', 'INF'],
#   'year': 2012,
#   'name': 'Sat. 11 Feb. 2012',
#   'day': 11,
#   'month': 2},
#  {'counts': ['0', '0', '0', 'INF'],
#   'year': 2012,
#   'name': 'Sun. 12 Feb. 2012',
#   'day': 12,
#   'month': 2},
#  {'counts': ['0', '0', '0', 'INF'],
#   'year': 2012,
#   'name': 'Mon. 13 Feb. 2012',
#   'day': 13,
#   'month': 2},
#  {'counts': ['0', '0', '0', 'INF'],
#   'year': 2012,
#   'name': 'Tue. 14 Feb. 2012',
#   'day': 14,
#   'month': 2},
#  {'counts': ['0', '0', '0', 'INF'],
#   'year': 2012,
#   'name': 'Wed. 15 Feb. 2012',
#   'day': 15,
#   'month': 2},
#  {'counts': ['0', '0', '0', 'INF'],
#   'year': 2012,
#   'name': 'Thu. 16 Feb. 2012',
#   'day': 16,
#   'month': 2},
#  {'counts': ['0', '0', '0', 'INF'],
#   'year': 2012,
#   'name': 'Fri. 17 Feb. 2012',
#   'day': 17,
#   'month': 2},
#  {'counts': ['0', '0', '0', 'INF'],
#   'year': 2012,
#   'name': 'Sat. 18 Feb. 2012',
#   'day': 18,
#   'month': 2},
#  {'counts': ['0', '0', '0', 'INF'],
#   'year': 2012,
#   'name': 'Sun. 19 Feb. 2012',
#   'day': 19,
#   'month': 2},
#  {'counts': ['0', '0', '0', 'INF'],
#   'year': 2012,
#   'name': 'Mon. 20 Feb. 2012',
#   'day': 20,
#   'month': 2},
#  {'counts': ['0', '0', '0', 'INF'],
#   'year': 2012,
#   'name': 'Tue. 21 Feb. 2012',
#   'day': 21,
#   'month': 2},
#  {'counts': ['0', '0', '0', 'INF'],
#   'year': 2012,
#   'name': 'Wed. 22 Feb. 2012',
#   'day': 22,
#   'month': 2},
#  {'counts': ['0', '0', '0', 'INF'],
#   'year': 2012,
#   'name': 'Thu. 23 Feb. 2012',
#   'day': 23,
#   'month': 2},
#  {'counts': ['0', '0', '0', 'INF'],
#   'year': 2012,
#   'name': 'Fri. 24 Feb. 2012',
#   'day': 24,
#   'month': 2},
#  {'counts': ['0', '0', '0', 'INF'],
#   'year': 2012,
#   'name': 'Sat. 25 Feb. 2012',
#   'day': 25,
#   'month': 2},
#  {'counts': ['0', '0', '0', 'INF'],
#   'year': 2012,
#   'name': 'Sun. 26 Feb. 2012',
#   'day': 26,
#   'month': 2},
#  {'counts': ['0', '0', '0', 'INF'],
#   'year': 2012,
#   'name': 'Mon. 27 Feb. 2012',
#   'day': 27,
#   'month': 2},
#  {'counts': ['0', '0', '0', 'INF'],
#   'year': 2012,
#   'name': 'Tue. 28 Feb. 2012',
#   'day': 28,
#   'month': 2},
#  {'counts': ['0', '0', '0', 'INF'],
#   'year': 2012,
#   'name': 'Wed. 29 Feb. 2012',
#   'day': 29,
#   'month': 2},
#  {'counts': ['0', '0', '0', 'INF'],
#   'year': 2012,
#   'name': 'Thu.  1 Mar. 2012',
#   'day': 1,
#   'month': 3},
#  {'counts': ['0', '0', '0', 'INF'],
#   'year': 2012,
#   'name': 'Fri.  2 Mar. 2012',
#   'day': 2,
#   'month': 3},
#  {'counts': ['0', '0', '0', 'INF'],
#   'year': 2012,
#   'name': 'Sat.  3 Mar. 2012',
#   'day': 3,
#   'month': 3},
#  {'counts': ['0', '0', '0', 'INF'],
#   'year': 2012,
#   'name': 'Sun.  4 Mar. 2012',
#   'day': 4,
#   'month': 3},
#  {'counts': ['0', '0', '0', 'INF'],
#   'year': 2012,
#   'name': 'Mon.  5 Mar. 2012',
#   'day': 5,
#   'month': 3},
#  {'counts': ['0', '0', '0', 'INF'],
#   'year': 2012,
#   'name': 'Tue.  6 Mar. 2012',
#   'day': 6,
#   'month': 3},
#  {'counts': ['0', '0', '0', 'INF'],
#   'year': 2012,
#   'name': 'Wed.  7 Mar. 2012',
#   'day': 7,
#   'month': 3},
#  {'counts': ['0', '0', '0', 'INF'],
#   'year': 2012,
#   'name': 'Thu.  8 Mar. 2012',
#   'day': 8,
#   'month': 3},
#  {'counts': ['0', '0', '0', 'INF'],
#   'year': 2012,
#   'name': 'Fri.  9 Mar. 2012',
#   'day': 9,
#   'month': 3},
#  {'counts': ['0', '0', '0', 'INF'],
#   'year': 2012,
#   'name': 'Sat. 10 Mar. 2012',
#   'day': 10,
#   'month': 3},
#  {'counts': ['0', '0', '0', 'INF'],
#   'year': 2012,
#   'name': 'Sun. 11 Mar. 2012',
#   'day': 11,
#   'month': 3},
#  {'counts': ['0', '0', '0', 'INF'],
#   'year': 2012,
#   'name': 'Mon. 12 Mar. 2012',
#   'day': 12,
#   'month': 3},
#  {'counts': ['0', '0', '0', 'INF'],
#   'year': 2012,
#   'name': 'Tue. 13 Mar. 2012',
#   'day': 13,
#   'month': 3},
#  {'counts': ['0', '0', '0', 'INF'],
#   'year': 2012,
#   'name': 'Wed. 14 Mar. 2012',
#   'day': 14,
#   'month': 3},
#  {'counts': ['0', '0', '0', 'INF'],
#   'year': 2012,
#   'name': 'Thu. 15 Mar. 2012',
#   'day': 15,
#   'month': 3},
#  {'counts': ['0', '0', '0', 'INF'],
#   'year': 2012,
#   'name': 'Fri. 16 Mar. 2012',
#   'day': 16,
#   'month': 3},
#  {'counts': ['0', '0', '0', 'INF'],
#   'year': 2012,
#   'name': 'Sat. 17 Mar. 2012',
#   'day': 17,
#   'month': 3},
#  {'counts': ['0', '0', '0', 'INF'],
#   'year': 2012,
#   'name': 'Sun. 18 Mar. 2012',
#   'day': 18,
#   'month': 3},
#  {'counts': ['0', '0', '0', 'INF'],
#   'year': 2012,
#   'name': 'Mon. 19 Mar. 2012',
#   'day': 19,
#   'month': 3},
#  {'counts': ['0', '0', '0', 'INF'],
#   'year': 2012,
#   'name': 'Tue. 20 Mar. 2012',
#   'day': 20,
#   'month': 3},
#  {'counts': ['0', '0', '0', 'INF'],
#   'year': 2012,
#   'name': 'Wed. 21 Mar. 2012',
#   'day': 21,
#   'month': 3},
#  {'counts': ['0', '0', '0', 'INF'],
#   'year': 2012,
#   'name': 'Thu. 22 Mar. 2012',
#   'day': 22,
#   'month': 3},
#  {'counts': ['0', '0', '0', 'INF'],
#   'year': 2012,
#   'name': 'Fri. 23 Mar. 2012',
#   'day': 23,
#   'month': 3},
#  {'counts': ['0', '0', '0', 'INF'],
#   'year': 2012,
#   'name': 'Sat. 24 Mar. 2012',
#   'day': 24,
#   'month': 3},
#  {'counts': ['0', '0', '0', 'INF'],
#   'year': 2012,
#   'name': 'Sun. 25 Mar. 2012',
#   'day': 25,
#   'month': 3},
#  {'counts': ['0', '0', '0', 'INF'],
#   'year': 2012,
#   'name': 'Mon. 26 Mar. 2012',
#   'day': 26,
#   'month': 3},
#  {'counts': ['0', '0', '0', 'INF'],
#   'year': 2012,
#   'name': 'Tue. 27 Mar. 2012',
#   'day': 27,
#   'month': 3},
#  {'counts': ['0', '0', '0', 'INF'],
#   'year': 2012,
#   'name': 'Wed. 28 Mar. 2012',
#   'day': 28,
#   'month': 3},
#  {'counts': ['0', '0', '0', 'INF'],
#   'year': 2012,
#   'name': 'Thu. 29 Mar. 2012',
#   'day': 29,
#   'month': 3},
#  {'counts': ['0', '0', '0', 'INF'],
#   'year': 2012,
#   'name': 'Fri. 30 Mar. 2012',
#   'day': 30,
#   'month': 3},
#  {'counts': ['0', '0', '0', 'INF'],
#   'year': 2012,
#   'name': 'Sat. 31 Mar. 2012',
#   'day': 31,
#   'month': 3},
#  {'counts': ['0', '0', '0', 'INF'],
#   'year': 2012,
#   'name': 'Sun.  1 Apr. 2012',
#   'day': 1,
#   'month': 4},
#  {'counts': ['0', '0', '0', 'INF'],
#   'year': 2012,
#   'name': 'Mon.  2 Apr. 2012',
#   'day': 2,
#   'month': 4},
#  {'counts': ['0', '0', '0', 'INF'],
#   'year': 2012,
#   'name': 'Tue.  3 Apr. 2012',
#   'day': 3,
#   'month': 4},
#  {'counts': ['0', '0', '0', 'INF'],
#   'year': 2012,
#   'name': 'Wed.  4 Apr. 2012',
#   'day': 4,
#   'month': 4},
#  {'counts': ['0', '0', '0', 'INF'],
#   'year': 2012,
#   'name': 'Thu.  5 Apr. 2012',
#   'day': 5,
#   'month': 4},
#  {'counts': ['0', '0', '0', 'INF'],
#   'year': 2012,
#   'name': 'Fri.  6 Apr. 2012',
#   'day': 6,
#   'month': 4},
#  {'counts': ['0', '0', '0', 'INF'],
#   'year': 2012,
#   'name': 'Sat.  7 Apr. 2012',
#   'day': 7,
#   'month': 4},
#  {'counts': ['0', '0', '0', 'INF'],
#   'year': 2012,
#   'name': 'Sun.  8 Apr. 2012',
#   'day': 8,
#   'month': 4},
#  {'counts': ['0', '0', '0', 'INF'],
#   'year': 2012,
#   'name': 'Mon.  9 Apr. 2012',
#   'day': 9,
#   'month': 4},
#  {'counts': ['0', '0', '0', 'INF'],
#   'year': 2012,
#   'name': 'Tue. 10 Apr. 2012',
#   'day': 10,
#   'month': 4},
#  {'counts': ['0', '0', '0', 'INF'],
#   'year': 2012,
#   'name': 'Wed. 11 Apr. 2012',
#   'day': 11,
#   'month': 4},
#  {'counts': ['0', '0', '0', 'INF'],
#   'year': 2012,
#   'name': 'Thu. 12 Apr. 2012',
#   'day': 12,
#   'month': 4},
#  {'counts': ['0', '0', '0', 'INF'],
#   'year': 2012,
#   'name': 'Fri. 13 Apr. 2012',
#   'day': 13,
#   'month': 4},
#  {'counts': ['0', '0', '0', 'INF'],
#   'year': 2012,
#   'name': 'Sat. 14 Apr. 2012',
#   'day': 14,
#   'month': 4},
#  {'counts': ['0', '0', '0', 'INF'],
#   'year': 2012,
#   'name': 'Sun. 15 Apr. 2012',
#   'day': 15,
#   'month': 4},
#  {'counts': ['0', '0', '0', 'INF'],
#   'year': 2012,
#   'name': 'Mon. 16 Apr. 2012',
#   'day': 16,
#   'month': 4},
#  {'counts': ['0', '0', '0', 'INF'],
#   'year': 2012,
#   'name': 'Tue. 17 Apr. 2012',
#   'day': 17,
#   'month': 4},
#  {'counts': ['0', '0', '0', 'INF'],
#   'year': 2012,
#   'name': 'Wed. 18 Apr. 2012',
#   'day': 18,
#   'month': 4},
#  {'counts': ['0', '0', '0', 'INF'],
#   'year': 2012,
#   'name': 'Thu. 19 Apr. 2012',
#   'day': 19,
#   'month': 4},
#  {'counts': ['0', '0', '0', 'INF'],
#   'year': 2012,
#   'name': 'Fri. 20 Apr. 2012',
#   'day': 20,
#   'month': 4},
#  {'counts': ['0', '0', '0', 'INF'],
#   'year': 2012,
#   'name': 'Sat. 21 Apr. 2012',
#   'day': 21,
#   'month': 4},
#  {'counts': ['0', '0', '0', 'INF'],
#   'year': 2012,
#   'name': 'Sun. 22 Apr. 2012',
#   'day': 22,
#   'month': 4},
#  {'counts': ['0', '0', '0', 'INF'],
#   'year': 2012,
#   'name': 'Mon. 23 Apr. 2012',
#   'day': 23,
#   'month': 4},
#  {'counts': ['0', '0', '0', 'INF'],
#   'year': 2012,
#   'name': 'Tue. 24 Apr. 2012',
#   'day': 24,
#   'month': 4},
#  {'counts': ['0', '0', '0', 'INF'],
#   'year': 2012,
#   'name': 'Wed. 25 Apr. 2012',
#   'day': 25,
#   'month': 4},
#  {'counts': ['0', '0', '0', 'INF'],
#   'year': 2012,
#   'name': 'Thu. 26 Apr. 2012',
#   'day': 26,
#   'month': 4},
#  {'counts': ['0', '0', '0', 'INF'],
#   'year': 2012,
#   'name': 'Fri. 27 Apr. 2012',
#   'day': 27,
#   'month': 4},
#  {'counts': ['0', '0', '0', 'INF'],
#   'year': 2012,
#   'name': 'Sat. 28 Apr. 2012',
#   'day': 28,
#   'month': 4},
#  {'counts': ['0', '0', '0', 'INF'],
#   'year': 2012,
#   'name': 'Sun. 29 Apr. 2012',
#   'day': 29,
#   'month': 4},
#  {'counts': ['0', '0', '0', 'INF'],
#   'year': 2012,
#   'name': 'Mon. 30 Apr. 2012',
#   'day': 30,
#   'month': 4},
#  {'counts': ['0', '0', '0', 'INF'],
#   'year': 2012,
#   'name': 'Tue.  1 May 2012',
#   'day': 1,
#   'month': 5},
#  {'counts': ['0', '0', '0', 'INF'],
#   'year': 2012,
#   'name': 'Wed.  2 May 2012',
#   'day': 2,
#   'month': 5},
#  {'counts': ['0', '0', '0', 'INF'],
#   'year': 2012,
#   'name': 'Thu.  3 May 2012',
#   'day': 3,
#   'month': 5},
#  {'counts': ['0', '0', '0', 'INF'],
#   'year': 2012,
#   'name': 'Fri.  4 May 2012',
#   'day': 4,
#   'month': 5},
#  {'counts': ['0', '0', '0', 'INF'],
#   'year': 2012,
#   'name': 'Sat.  5 May 2012',
#   'day': 5,
#   'month': 5},
#  {'counts': ['0', '0', '0', 'INF'],
#   'year': 2012,
#   'name': 'Sun.  6 May 2012',
#   'day': 6,
#   'month': 5},
#  {'counts': ['0', '0', '0', 'INF'],
#   'year': 2012,
#   'name': 'Mon.  7 May 2012',
#   'day': 7,
#   'month': 5},
#  {'counts': ['0', '0', '0', 'INF'],
#   'year': 2012,
#   'name': 'Tue.  8 May 2012',
#   'day': 8,
#   'month': 5},
#  {'counts': ['0', '0', '0', 'INF'],
#   'year': 2012,
#   'name': 'Wed.  9 May 2012',
#   'day': 9,
#   'month': 5},
#  {'counts': ['0', '0', '0', 'INF'],
#   'year': 2012,
#   'name': 'Thu. 10 May 2012',
#   'day': 10,
#   'month': 5},
#  {'counts': ['0', '0', '0', 'INF'],
#   'year': 2012,
#   'name': 'Fri. 11 May 2012',
#   'day': 11,
#   'month': 5},
#  {'counts': ['0', '0', '0', 'INF'],
#   'year': 2012,
#   'name': 'Sat. 12 May 2012',
#   'day': 12,
#   'month': 5},
#  {'counts': ['0', '0', '0', 'INF'],
#   'year': 2012,
#   'name': 'Sun. 13 May 2012',
#   'day': 13,
#   'month': 5},
#  {'counts': ['0', '0', '0', 'INF'],
#   'year': 2012,
#   'name': 'Mon. 14 May 2012',
#   'day': 14,
#   'month': 5},
#  {'counts': ['0', '0', '0', 'INF'],
#   'year': 2012,
#   'name': 'Tue. 15 May 2012',
#   'day': 15,
#   'month': 5},
#  {'counts': ['0', '0', '0', 'INF'],
#   'year': 2012,
#   'name': 'Wed. 16 May 2012',
#   'day': 16,
#   'month': 5},
#  {'counts': ['0', '0', '0', 'INF'],
#   'year': 2012,
#   'name': 'Thu. 17 May 2012',
#   'day': 17,
#   'month': 5},
#  {'counts': ['0', '0', '0', 'INF'],
#   'year': 2012,
#   'name': 'Fri. 18 May 2012',
#   'day': 18,
#   'month': 5},
#  {'counts': ['0', '0', '0', 'INF'],
#   'year': 2012,
#   'name': 'Sat. 19 May 2012',
#   'day': 19,
#   'month': 5},
#  {'counts': ['0', '0', '0', 'INF'],
#   'year': 2012,
#   'name': 'Sun. 20 May 2012',
#   'day': 20,
#   'month': 5},
#  {'counts': ['0', '0', '0', 'INF'],
#   'year': 2012,
#   'name': 'Mon. 21 May 2012',
#   'day': 21,
#   'month': 5},
#  {'counts': ['0', '0', '0', 'INF'],
#   'year': 2012,
#   'name': 'Tue. 22 May 2012',
#   'day': 22,
#   'month': 5},
#  {'counts': ['0', '0', '0', 'INF'],
#   'year': 2012,
#   'name': 'Wed. 23 May 2012',
#   'day': 23,
#   'month': 5},
#  {'counts': ['0', '0', '0', 'INF'],
#   'year': 2012,
#   'name': 'Thu. 24 May 2012',
#   'day': 24,
#   'month': 5},
#  {'counts': ['0', '0', '0', 'INF'],
#   'year': 2012,
#   'name': 'Fri. 25 May 2012',
#   'day': 25,
#   'month': 5},
#  {'counts': ['0', '0', '0', 'INF'],
#   'year': 2012,
#   'name': 'Sat. 26 May 2012',
#   'day': 26,
#   'month': 5},
#  {'counts': ['0', '0', '0', 'INF'],
#   'year': 2012,
#   'name': 'Sun. 27 May 2012',
#   'day': 27,
#   'month': 5},
#  {'counts': ['0', '0', '0', 'INF'],
#   'year': 2012,
#   'name': 'Mon. 28 May 2012',
#   'day': 28,
#   'month': 5},
#  {'counts': ['0', '0', '0', 'INF'],
#   'year': 2012,
#   'name': 'Tue. 29 May 2012',
#   'day': 29,
#   'month': 5},
#  {'counts': ['0', '0', '0', 'INF'],
#   'year': 2012,
#   'name': 'Wed. 30 May 2012',
#   'day': 30,
#   'month': 5},
#  {'counts': ['0', '0', '0', 'INF'],
#   'year': 2012,
#   'name': 'Thu. 31 May 2012',
#   'day': 31,
#   'month': 5},
#  {'counts': ['0', '0', '0', 'INF'],
#   'year': 2012,
#   'name': 'Fri.  1 Jun. 2012',
#   'day': 1,
#   'month': 6},
#  {'counts': ['0', '0', '0', 'INF'],
#   'year': 2012,
#   'name': 'Sat.  2 Jun. 2012',
#   'day': 2,
#   'month': 6},
#  {'counts': ['0', '0', '0', 'INF'],
#   'year': 2012,
#   'name': 'Sun.  3 Jun. 2012',
#   'day': 3,
#   'month': 6},
#  {'counts': ['0', '0', '0', 'INF'],
#   'year': 2012,
#   'name': 'Mon.  4 Jun. 2012',
#   'day': 4,
#   'month': 6},
#  {'counts': ['0', '0', '0', 'INF'],
#   'year': 2012,
#   'name': 'Tue.  5 Jun. 2012',
#   'day': 5,
#   'month': 6},
#  {'counts': ['0', '0', '0', 'INF'],
#   'year': 2012,
#   'name': 'Wed.  6 Jun. 2012',
#   'day': 6,
#   'month': 6},
#  {'counts': ['0', '0', '0', 'INF'],
#   'year': 2012,
#   'name': 'Thu.  7 Jun. 2012',
#   'day': 7,
#   'month': 6},
#  {'counts': ['0', '0', '0', 'INF'],
#   'year': 2012,
#   'name': 'Fri.  8 Jun. 2012',
#   'day': 8,
#   'month': 6},
#  {'counts': ['0', '0', '0', 'INF'],
#   'year': 2012,
#   'name': 'Sat.  9 Jun. 2012',
#   'day': 9,
#   'month': 6},
#  {'counts': ['0', '0', '0', 'INF'],
#   'year': 2012,
#   'name': 'Sun. 10 Jun. 2012',
#   'day': 10,
#   'month': 6},
#  {'counts': ['0', '0', '0', 'INF'],
#   'year': 2012,
#   'name': 'Mon. 11 Jun. 2012',
#   'day': 11,
#   'month': 6},
#  {'counts': ['0', '0', '0', 'INF'],
#   'year': 2012,
#   'name': 'Tue. 12 Jun. 2012',
#   'day': 12,
#   'month': 6},
#  {'counts': ['0', '0', '0', 'INF'],
#   'year': 2012,
#   'name': 'Wed. 13 Jun. 2012',
#   'day': 13,
#   'month': 6},
#  {'counts': ['0', '0', '0', 'INF'],
#   'year': 2012,
#   'name': 'Thu. 14 Jun. 2012',
#   'day': 14,
#   'month': 6},
#  {'counts': ['0', '0', '0', 'INF'],
#   'year': 2012,
#   'name': 'Fri. 15 Jun. 2012',
#   'day': 15,
#   'month': 6},
#  {'counts': ['0', '0', '0', 'INF'],
#   'year': 2012,
#   'name': 'Sat. 16 Jun. 2012',
#   'day': 16,
#   'month': 6},
#  {'counts': ['0', '0', '0', 'INF'],
#   'year': 2012,
#   'name': 'Sun. 17 Jun. 2012',
#   'day': 17,
#   'month': 6},
#  {'counts': ['0', '0', '0', 'INF'],
#   'year': 2012,
#   'name': 'Mon. 18 Jun. 2012',
#   'day': 18,
#   'month': 6},
#  {'counts': ['0', '0', '0', 'INF'],
#   'year': 2012,
#   'name': 'Tue. 19 Jun. 2012',
#   'day': 19,
#   'month': 6},
#  {'counts': ['0', '0', '0', 'INF'],
#   'year': 2012,
#   'name': 'Wed. 20 Jun. 2012',
#   'day': 20,
#   'month': 6},
#  {'counts': ['0', '0', '0', 'INF'],
#   'year': 2012,
#   'name': 'Thu. 21 Jun. 2012',
#   'day': 21,
#   'month': 6},
#  {'counts': ['0', '0', '0', 'INF'],
#   'year': 2012,
#   'name': 'Fri. 22 Jun. 2012',
#   'day': 22,
#   'month': 6},
#  {'counts': ['0', '0', '0', 'INF'],
#   'year': 2012,
#   'name': 'Sat. 23 Jun. 2012',
#   'day': 23,
#   'month': 6},
#  {'counts': ['0', '0', '0', 'INF'],
#   'year': 2012,
#   'name': 'Sun. 24 Jun. 2012',
#   'day': 24,
#   'month': 6},
#  {'counts': ['0', '0', '0', 'INF'],
#   'year': 2012,
#   'name': 'Mon. 25 Jun. 2012',
#   'day': 25,
#   'month': 6},
#  {'counts': ['0', '0', '0', 'INF'],
#   'year': 2012,
#   'name': 'Tue. 26 Jun. 2012',
#   'day': 26,
#   'month': 6},
#  {'counts': ['0', '0', '0', 'INF'],
#   'year': 2012,
#   'name': 'Wed. 27 Jun. 2012',
#   'day': 27,
#   'month': 6},
#  {'counts': ['0', '0', '0', 'INF'],
#   'year': 2012,
#   'name': 'Thu. 28 Jun. 2012',
#   'day': 28,
#   'month': 6},
#  {'counts': ['0', '0', '0', 'INF'],
#   'year': 2012,
#   'name': 'Fri. 29 Jun. 2012',
#   'day': 29,
#   'month': 6},
#  {'counts': ['0', '0', '0', 'INF'],
#   'year': 2012,
#   'name': 'Sat. 30 Jun. 2012',
#   'day': 30,
#   'month': 6},
#  {'counts': ['0', '0', '0', 'INF'],
#   'year': 2012,
#   'name': 'Sun.  1 Jul. 2012',
#   'day': 1,
#   'month': 7},
#  {'counts': ['0', '0', '0', 'INF'],
#   'year': 2012,
#   'name': 'Mon.  2 Jul. 2012',
#   'day': 2,
#   'month': 7},
#  {'counts': ['0', '0', '0', 'INF'],
#   'year': 2012,
#   'name': 'Tue.  3 Jul. 2012',
#   'day': 3,
#   'month': 7},
#  {'counts': ['0', '0', '0', 'INF'],
#   'year': 2012,
#   'name': 'Wed.  4 Jul. 2012',
#   'day': 4,
#   'month': 7},
#  {'counts': ['0', '0', '0', 'INF'],
#   'year': 2012,
#   'name': 'Thu.  5 Jul. 2012',
#   'day': 5,
#   'month': 7},
#  {'counts': ['0', '0', '0', 'INF'],
#   'year': 2012,
#   'name': 'Fri.  6 Jul. 2012',
#   'day': 6,
#   'month': 7},
#  {'counts': ['0', '0', '0', 'INF'],
#   'year': 2012,
#   'name': 'Sat.  7 Jul. 2012',
#   'day': 7,
#   'month': 7},
#  {'counts': ['0', '0', '0', 'INF'],
#   'year': 2012,
#   'name': 'Sun.  8 Jul. 2012',
#   'day': 8,
#   'month': 7},
#  {'counts': ['0', '0', '0', 'INF'],
#   'year': 2012,
#   'name': 'Mon.  9 Jul. 2012',
#   'day': 9,
#   'month': 7},
#  {'counts': ['0', '0', '0', 'INF'],
#   'year': 2012,
#   'name': 'Tue. 10 Jul. 2012',
#   'day': 10,
#   'month': 7},
#  {'counts': ['0', '0', '0', 'INF'],
#   'year': 2012,
#   'name': 'Wed. 11 Jul. 2012',
#   'day': 11,
#   'month': 7},
#  {'counts': ['0', '0', '0', 'INF'],
#   'year': 2012,
#   'name': 'Thu. 12 Jul. 2012',
#   'day': 12,
#   'month': 7},
#  {'counts': ['0', '0', '0', 'INF'],
#   'year': 2012,
#   'name': 'Fri. 13 Jul. 2012',
#   'day': 13,
#   'month': 7},
#  {'counts': ['0', '0', '0', 'INF'],
#   'year': 2012,
#   'name': 'Sat. 14 Jul. 2012',
#   'day': 14,
#   'month': 7},
#  {'counts': ['0', '0', '0', 'INF'],
#   'year': 2012,
#   'name': 'Sun. 15 Jul. 2012',
#   'day': 15,
#   'month': 7},
#  {'counts': ['0', '0', '0', 'INF'],
#   'year': 2012,
#   'name': 'Mon. 16 Jul. 2012',
#   'day': 16,
#   'month': 7},
#  {'counts': ['0', '0', '0', 'INF'],
#   'year': 2012,
#   'name': 'Tue. 17 Jul. 2012',
#   'day': 17,
#   'month': 7},
#  {'counts': ['0', '0', '0', 'INF'],
#   'year': 2012,
#   'name': 'Wed. 18 Jul. 2012',
#   'day': 18,
#   'month': 7},
#  {'counts': ['0', '0', '0', 'INF'],
#   'year': 2012,
#   'name': 'Thu. 19 Jul. 2012',
#   'day': 19,
#   'month': 7},
#  {'counts': ['0', '0', '0', 'INF'],
#   'year': 2012,
#   'name': 'Fri. 20 Jul. 2012',
#   'day': 20,
#   'month': 7},
#  {'counts': ['0', '0', '0', 'INF'],
#   'year': 2012,
#   'name': 'Sat. 21 Jul. 2012',
#   'day': 21,
#   'month': 7},
#  {'counts': ['0', '0', '0', 'INF'],
#   'year': 2012,
#   'name': 'Sun. 22 Jul. 2012',
#   'day': 22,
#   'month': 7},
#  {'counts': ['0', '0', '0', 'INF'],
#   'year': 2012,
#   'name': 'Mon. 23 Jul. 2012',
#   'day': 23,
#   'month': 7},
#  {'counts': ['0', '0', '0', 'INF'],
#   'year': 2012,
#   'name': 'Tue. 24 Jul. 2012',
#   'day': 24,
#   'month': 7},
#  {'counts': ['0', '0', '0', 'INF'],
#   'year': 2012,
#   'name': 'Wed. 25 Jul. 2012',
#   'day': 25,
#   'month': 7},
#  {'counts': ['0', '0', '0', 'INF'],
#   'year': 2012,
#   'name': 'Thu. 26 Jul. 2012',
#   'day': 26,
#   'month': 7},
#  {'counts': ['0', '0', '0', 'INF'],
#   'year': 2012,
#   'name': 'Fri. 27 Jul. 2012',
#   'day': 27,
#   'month': 7},
#  {'counts': ['0', '0', '0', 'INF'],
#   'year': 2012,
#   'name': 'Sat. 28 Jul. 2012',
#   'day': 28,
#   'month': 7},
#  {'counts': ['0', '0', '0', 'INF'],
#   'year': 2012,
#   'name': 'Sun. 29 Jul. 2012',
#   'day': 29,
#   'month': 7},
#  {'counts': ['0', '0', '0', 'INF'],
#   'year': 2012,
#   'name': 'Mon. 30 Jul. 2012',
#   'day': 30,
#   'month': 7},
#  {'counts': ['0', '0', '0', 'INF'],
#   'year': 2012,
#   'name': 'Tue. 31 Jul. 2012',
#   'day': 31,
#   'month': 7},
#  {'counts': ['0', '0', '0', 'INF'],
#   'year': 2012,
#   'name': 'Wed.  1 Aug. 2012',
#   'day': 1,
#   'month': 8},
#  {'counts': ['0', '0', '0', 'INF'],
#   'year': 2012,
#   'name': 'Thu.  2 Aug. 2012',
#   'day': 2,
#   'month': 8},
#  {'counts': ['0', '0', '0', 'INF'],
#   'year': 2012,
#   'name': 'Fri.  3 Aug. 2012',
#   'day': 3,
#   'month': 8},
#  {'counts': ['0', '0', '0', 'INF'],
#   'year': 2012,
#   'name': 'Sat.  4 Aug. 2012',
#   'day': 4,
#   'month': 8},
#  {'counts': ['0', '0', '0', 'INF'],
#   'year': 2012,
#   'name': 'Sun.  5 Aug. 2012',
#   'day': 5,
#   'month': 8},
#  {'counts': ['0', '0', '0', 'INF'],
#   'year': 2012,
#   'name': 'Mon.  6 Aug. 2012',
#   'day': 6,
#   'month': 8},
#  {'counts': ['0', '0', '0', 'INF'],
#   'year': 2012,
#   'name': 'Tue.  7 Aug. 2012',
#   'day': 7,
#   'month': 8},
#  {'counts': ['0', '0', '0', 'INF'],
#   'year': 2012,
#   'name': 'Wed.  8 Aug. 2012',
#   'day': 8,
#   'month': 8},
#  {'counts': ['0', '0', '0', 'INF'],
#   'year': 2012,
#   'name': 'Thu.  9 Aug. 2012',
#   'day': 9,
#   'month': 8},
#  {'counts': ['0', '0', '0', 'INF'],
#   'year': 2012,
#   'name': 'Fri. 10 Aug. 2012',
#   'day': 10,
#   'month': 8},
#  {'counts': ['0', '0', '0', 'INF'],
#   'year': 2012,
#   'name': 'Sat. 11 Aug. 2012',
#   'day': 11,
#   'month': 8},
#  {'counts': ['0', '0', '0', 'INF'],
#   'year': 2012,
#   'name': 'Sun. 12 Aug. 2012',
#   'day': 12,
#   'month': 8},
#  {'counts': ['0', '0', '0', 'INF'],
#   'year': 2012,
#   'name': 'Mon. 13 Aug. 2012',
#   'day': 13,
#   'month': 8},
#  {'counts': ['0', '0', '0', 'INF'],
#   'year': 2012,
#   'name': 'Tue. 14 Aug. 2012',
#   'day': 14,
#   'month': 8},
#  {'counts': ['0', '0', '0', 'INF'],
#   'year': 2012,
#   'name': 'Wed. 15 Aug. 2012',
#   'day': 15,
#   'month': 8},
#  {'counts': ['0', '0', '0', 'INF'],
#   'year': 2012,
#   'name': 'Thu. 16 Aug. 2012',
#   'day': 16,
#   'month': 8},
#  {'counts': ['0', '0', '0', 'INF'],
#   'year': 2012,
#   'name': 'Fri. 17 Aug. 2012',
#   'day': 17,
#   'month': 8},
#  {'counts': ['0', '0', '0', 'INF'],
#   'year': 2012,
#   'name': 'Sat. 18 Aug. 2012',
#   'day': 18,
#   'month': 8},
#  {'counts': ['0', '0', '0', 'INF'],
#   'year': 2012,
#   'name': 'Sun. 19 Aug. 2012',
#   'day': 19,
#   'month': 8},
#  {'counts': ['0', '0', '0', 'INF'],
#   'year': 2012,
#   'name': 'Mon. 20 Aug. 2012',
#   'day': 20,
#   'month': 8},
#  {'counts': ['0', '0', '0', 'INF'],
#   'year': 2012,
#   'name': 'Tue. 21 Aug. 2012',
#   'day': 21,
#   'month': 8},
#  {'counts': ['0', '0', '0', 'INF'],
#   'year': 2012,
#   'name': 'Wed. 22 Aug. 2012',
#   'day': 22,
#   'month': 8},
#  {'counts': ['0', '0', '0', 'INF'],
#   'year': 2012,
#   'name': 'Thu. 23 Aug. 2012',
#   'day': 23,
#   'month': 8},
#  {'counts': ['0', '0', '0', 'INF'],
#   'year': 2012,
#   'name': 'Fri. 24 Aug. 2012',
#   'day': 24,
#   'month': 8},
#  {'counts': ['0', '0', '0', 'INF'],
#   'year': 2012,
#   'name': 'Sat. 25 Aug. 2012',
#   'day': 25,
#   'month': 8},
#  {'counts': ['0', '0', '0', 'INF'],
#   'year': 2012,
#   'name': 'Sun. 26 Aug. 2012',
#   'day': 26,
#   'month': 8},
#  {'counts': ['0', '0', '0', 'INF'],
#   'year': 2012,
#   'name': 'Mon. 27 Aug. 2012',
#   'day': 27,
#   'month': 8},
#  {'counts': ['0', '0', '0', 'INF'],
#   'year': 2012,
#   'name': 'Tue. 28 Aug. 2012',
#   'day': 28,
#   'month': 8},
#  {'counts': ['0', '0', '0', 'INF'],
#   'year': 2012,
#   'name': 'Wed. 29 Aug. 2012',
#   'day': 29,
#   'month': 8},
#  {'counts': ['0', '0', '0', 'INF'],
#   'year': 2012,
#   'name': 'Thu. 30 Aug. 2012',
#   'day': 30,
#   'month': 8},
#  {'counts': ['0', '0', '0', 'INF'],
#   'year': 2012,
#   'name': 'Fri. 31 Aug. 2012',
#   'day': 31,
#   'month': 8},
#  {'counts': ['0', '0', '0', 'INF'],
#   'year': 2012,
#   'name': 'Sat.  1 Sep. 2012',
#   'day': 1,
#   'month': 9},
#  {'counts': ['0', '0', '0', 'INF'],
#   'year': 2012,
#   'name': 'Sun.  2 Sep. 2012',
#   'day': 2,
#   'month': 9},
#  {'counts': ['0', '0', '0', 'INF'],
#   'year': 2012,
#   'name': 'Mon.  3 Sep. 2012',
#   'day': 3,
#   'month': 9},
#  {'counts': ['0', '0', '0', 'INF'],
#   'year': 2012,
#   'name': 'Tue.  4 Sep. 2012',
#   'day': 4,
#   'month': 9},
#  {'counts': ['0', '0', '0', 'INF'],
#   'year': 2012,
#   'name': 'Wed.  5 Sep. 2012',
#   'day': 5,
#   'month': 9},
#  {'counts': ['0', '0', '0', 'INF'],
#   'year': 2012,
#   'name': 'Thu.  6 Sep. 2012',
#   'day': 6,
#   'month': 9},
#  {'counts': ['0', '0', '0', 'INF'],
#   'year': 2012,
#   'name': 'Fri.  7 Sep. 2012',
#   'day': 7,
#   'month': 9},
#  {'counts': ['0', '0', '0', 'INF'],
#   'year': 2012,
#   'name': 'Sat.  8 Sep. 2012',
#   'day': 8,
#   'month': 9},
#  {'counts': ['0', '0', '0', 'INF'],
#   'year': 2012,
#   'name': 'Sun.  9 Sep. 2012',
#   'day': 9,
#   'month': 9},
#  {'counts': ['0', '0', '0', 'INF'],
#   'year': 2012,
#   'name': 'Mon. 10 Sep. 2012',
#   'day': 10,
#   'month': 9},
#  {'counts': ['0', '0', '0', 'INF'],
#   'year': 2012,
#   'name': 'Tue. 11 Sep. 2012',
#   'day': 11,
#   'month': 9},
#  {'counts': ['0', '0', '0', 'INF'],
#   'year': 2012,
#   'name': 'Wed. 12 Sep. 2012',
#   'day': 12,
#   'month': 9},
#  {'counts': ['0', '0', '0', 'INF'],
#   'year': 2012,
#   'name': 'Thu. 13 Sep. 2012',
#   'day': 13,
#   'month': 9},
#  {'counts': ['0', '0', '0', 'INF'],
#   'year': 2012,
#   'name': 'Fri. 14 Sep. 2012',
#   'day': 14,
#   'month': 9},
#  {'counts': ['0', '0', '0', 'INF'],
#   'year': 2012,
#   'name': 'Sat. 15 Sep. 2012',
#   'day': 15,
#   'month': 9},
#  {'counts': ['0', '0', '0', 'INF'],
#   'year': 2012,
#   'name': 'Sun. 16 Sep. 2012',
#   'day': 16,
#   'month': 9},
#  {'counts': ['0', '0', '0', 'INF'],
#   'year': 2012,
#   'name': 'Mon. 17 Sep. 2012',
#   'day': 17,
#   'month': 9},
#  {'counts': ['0', '0', '0', 'INF'],
#   'year': 2012,
#   'name': 'Tue. 18 Sep. 2012',
#   'day': 18,
#   'month': 9},
#  {'counts': ['0', '0', '0', 'INF'],
#   'year': 2012,
#   'name': 'Wed. 19 Sep. 2012',
#   'day': 19,
#   'month': 9},
#  {'counts': ['0', '0', '0', 'INF'],
#   'year': 2012,
#   'name': 'Thu. 20 Sep. 2012',
#   'day': 20,
#   'month': 9},
#  {'counts': ['0', '0', '0', 'INF'],
#   'year': 2012,
#   'name': 'Fri. 21 Sep. 2012',
#   'day': 21,
#   'month': 9},
#  {'counts': ['0', '0', '0', 'INF'],
#   'year': 2012,
#   'name': 'Sat. 22 Sep. 2012',
#   'day': 22,
#   'month': 9},
#  {'counts': ['0', '0', '0', 'INF'],
#   'year': 2012,
#   'name': 'Sun. 23 Sep. 2012',
#   'day': 23,
#   'month': 9},
#  {'counts': ['0', '0', '0', 'INF'],
#   'year': 2012,
#   'name': 'Mon. 24 Sep. 2012',
#   'day': 24,
#   'month': 9},
#  {'counts': ['0', '0', '0', 'INF'],
#   'year': 2012,
#   'name': 'Tue. 25 Sep. 2012',
#   'day': 25,
#   'month': 9},
#  {'counts': ['0', '0', '0', 'INF'],
#   'year': 2012,
#   'name': 'Wed. 26 Sep. 2012',
#   'day': 26,
#   'month': 9},
#  {'counts': ['0', '0', '0', 'INF'],
#   'year': 2012,
#   'name': 'Thu. 27 Sep. 2012',
#   'day': 27,
#   'month': 9},
#  {'counts': ['0', '0', '0', 'INF'],
#   'year': 2012,
#   'name': 'Fri. 28 Sep. 2012',
#   'day': 28,
#   'month': 9},
#  {'counts': ['0', '0', '0', 'INF'],
#   'year': 2012,
#   'name': 'Sat. 29 Sep. 2012',
#   'day': 29,
#   'month': 9},
#  {'counts': ['0', '0', '0', 'INF'],
#   'year': 2012,
#   'name': 'Sun. 30 Sep. 2012',
#   'day': 30,
#   'month': 9},
#  {'counts': ['0', '0', '0', 'INF'],
#   'year': 2012,
#   'name': 'Mon.  1 Oct. 2012',
#   'day': 1,
#   'month': 10},
#  {'counts': ['0', '0', '0', 'INF'],
#   'year': 2012,
#   'name': 'Tue.  2 Oct. 2012',
#   'day': 2,
#   'month': 10},
#  {'counts': ['0', '0', '0', 'INF'],
#   'year': 2012,
#   'name': 'Wed.  3 Oct. 2012',
#   'day': 3,
#   'month': 10},
#  {'counts': ['0', '0', '0', 'INF'],
#   'year': 2012,
#   'name': 'Thu.  4 Oct. 2012',
#   'day': 4,
#   'month': 10},
#  {'counts': ['0', '0', '0', 'INF'],
#   'year': 2012,
#   'name': 'Fri.  5 Oct. 2012',
#   'day': 5,
#   'month': 10},
#  {'counts': ['0', '0', '0', 'INF'],
#   'year': 2012,
#   'name': 'Sat.  6 Oct. 2012',
#   'day': 6,
#   'month': 10},
#  {'counts': ['0', '0', '0', 'INF'],
#   'year': 2012,
#   'name': 'Sun.  7 Oct. 2012',
#   'day': 7,
#   'month': 10},
#  {'counts': ['1', '1', '1', '1'],
#   'year': 2012,
#   'name': 'Mon.  8 Oct. 2012',
#   'day': 8,
#   'month': 10},
#  {'counts': ['0', '0', '0', 'INF'],
#   'year': 2012,
#   'name': 'Tue.  9 Oct. 2012',
#   'day': 9,
#   'month': 10},
#  {'counts': ['0', '0', '0', 'INF'],
#   'year': 2012,
#   'name': 'Wed. 10 Oct. 2012',
#   'day': 10,
#   'month': 10},
#  {'counts': ['0', '0', '0', 'INF'],
#   'year': 2012,
#   'name': 'Thu. 11 Oct. 2012',
#   'day': 11,
#   'month': 10},
#  {'counts': ['0', '0', '0', 'INF'],
#   'year': 2012,
#   'name': 'Fri. 12 Oct. 2012',
#   'day': 12,
#   'month': 10},
#  {'counts': ['0', '0', '0', 'INF'],
#   'year': 2012,
#   'name': 'Sat. 13 Oct. 2012',
#   'day': 13,
#   'month': 10},
#  {'counts': ['0', '0', '0', 'INF'],
#   'year': 2012,
#   'name': 'Sun. 14 Oct. 2012',
#   'day': 14,
#   'month': 10},
#  {'counts': ['0', '0', '0', 'INF'],
#   'year': 2012,
#   'name': 'Mon. 15 Oct. 2012',
#   'day': 15,
#   'month': 10},
#  {'counts': ['4', '3', '1', '0.6666666666'],
#   'year': 2012,
#   'name': 'Tue. 16 Oct. 2012',
#   'day': 16,
#   'month': 10},
#  {'counts': ['32', '11', '9', '0.2727272727'],
#   'year': 2012,
#   'name': 'Wed. 17 Oct. 2012',
#   'day': 17,
#   'month': 10},
#  {'counts': ['550680', '185607', '181942', '0.3105378568'],
#   'year': 2012,
#   'name': 'Thu. 18 Oct. 2012',
#   'day': 18,
#   'month': 10},
#  {'counts': ['7384524', '2522740', '2366966', '0.3146360747'],
#   'year': 2012,
#   'name': 'Fri. 19 Oct. 2012',
#   'day': 19,
#   'month': 10},
#  {'counts': ['7416971', '2514948', '2352663', '0.3100251012'],
#   'year': 2012,
#   'name': 'Sat. 20 Oct. 2012',
#   'day': 20,
#   'month': 10},
#  {'counts': ['7369053', '2501924', '2340518', '0.3133657474'],
#   'year': 2012,
#   'name': 'Sun. 21 Oct. 2012',
#   'day': 21,
#   'month': 10},
#  {'counts': ['7563950', '2606561', '2446982', '0.318720472'],
#   'year': 2012,
#   'name': 'Mon. 22 Oct. 2012',
#   'day': 22,
#   'month': 10},
#  {'counts': ['7626495', '2653545', '2490659', '0.3188372256'],
#   'year': 2012,
#   'name': 'Tue. 23 Oct. 2012',
#   'day': 23,
#   'month': 10},
#  {'counts': ['8019731', '2814017', '2648374', '0.3028694018'],
#   'year': 2012,
#   'name': 'Wed. 24 Oct. 2012',
#   'day': 24,
#   'month': 10},
#  {'counts': ['7732014', '2716399', '2553910', '0.3113154347'],
#   'year': 2012,
#   'name': 'Thu. 25 Oct. 2012',
#   'day': 25,
#   'month': 10},
#  {'counts': ['7506557', '2624503', '2463787', '0.3102596764'],
#   'year': 2012,
#   'name': 'Fri. 26 Oct. 2012',
#   'day': 26,
#   'month': 10},
#  {'counts': ['7528705', '2595434', '2428113', '0.3049940806'],
#   'year': 2012,
#   'name': 'Sat. 27 Oct. 2012',
#   'day': 27,
#   'month': 10},
#  {'counts': ['7741075', '2660168', '2489647', '0.3047509982'],
#   'year': 2012,
#   'name': 'Sun. 28 Oct. 2012',
#   'day': 28,
#   'month': 10},
#  {'counts': ['7947722', '2774823', '2603578', '0.3155681869'],
#   'year': 2012,
#   'name': 'Mon. 29 Oct. 2012',
#   'day': 29,
#   'month': 10},
#  {'counts': ['7805080', '2732133', '2564156', '0.3246135134'],
#   'year': 2012,
#   'name': 'Tue. 30 Oct. 2012',
#   'day': 30,
#   'month': 10},
#  {'counts': ['7575212', '2622328', '2456520', '0.3118080179'],
#   'year': 2012,
#   'name': 'Wed. 31 Oct. 2012',
#   'day': 31,
#   'month': 10},
#  {'counts': ['7559253', '2659634', '2492083', '0.3235203396'],
#   'year': 2012,
#   'name': 'Thu.  1 Nov. 2012',
#   'day': 1,
#   'month': 11},
#  {'counts': ['7728059', '2751560', '2582104', '0.3255450522'],
#   'year': 2012,
#   'name': 'Fri.  2 Nov. 2012',
#   'day': 2,
#   'month': 11},
#  {'counts': ['7817593', '2721499', '2546393', '0.3159838904'],
#   'year': 2012,
#   'name': 'Sat.  3 Nov. 2012',
#   'day': 3,
#   'month': 11},
#  {'counts': ['8281098', '2855448', '2665907', '0.3121976316'],
#   'year': 2012,
#   'name': 'Sun.  4 Nov. 2012',
#   'day': 4,
#   'month': 11},
#  {'counts': ['8030066', '2763455', '2594277', '0.3119254347'],
#   'year': 2012,
#   'name': 'Mon.  5 Nov. 2012',
#   'day': 5,
#   'month': 11},
#  {'counts': ['7716068', '2717064', '2548068', '0.3192525984'],
#   'year': 2012,
#   'name': 'Tue.  6 Nov. 2012',
#   'day': 6,
#   'month': 11},
#  {'counts': ['7728532', '2733565', '2564898', '0.3194141191'],
#   'year': 2012,
#   'name': 'Wed.  7 Nov. 2012',
#   'day': 7,
#   'month': 11},
#  {'counts': ['7966880', '2796070', '2625580', '0.3122160905'],
#   'year': 2012,
#   'name': 'Thu.  8 Nov. 2012',
#   'day': 8,
#   'month': 11},
#  {'counts': ['7562921', '2671770', '2500546', '0.3196790838'],
#   'year': 2012,
#   'name': 'Fri.  9 Nov. 2012',
#   'day': 9,
#   'month': 11},
#  {'counts': ['7462495', '2626554', '2450545', '0.3173049008'],
#   'year': 2012,
#   'name': 'Sat. 10 Nov. 2012',
#   'day': 10,
#   'month': 11},
#  {'counts': ['7313862', '2584777', '2412514', '0.3206128443'],
#   'year': 2012,
#   'name': 'Sun. 11 Nov. 2012',
#   'day': 11,
#   'month': 11},
#  {'counts': ['7556024', '2681810', '2511194', '0.3285200808'],
#   'year': 2012,
#   'name': 'Mon. 12 Nov. 2012',
#   'day': 12,
#   'month': 11},
#  {'counts': ['7316772', '2609269', '2443976', '0.3327706769'],
#   'year': 2012,
#   'name': 'Tue. 13 Nov. 2012',
#   'day': 13,
#   'month': 11},
#  {'counts': ['7311620', '2633794', '2467245', '0.3357782014'],
#   'year': 2012,
#   'name': 'Wed. 14 Nov. 2012',
#   'day': 14,
#   'month': 11},
#  {'counts': ['7193596', '2594934', '2431273', '0.3343713764'],
#   'year': 2012,
#   'name': 'Thu. 15 Nov. 2012',
#   'day': 15,
#   'month': 11},
#  {'counts': ['7495353', '2671019', '2502038', '0.3257951834'],
#   'year': 2012,
#   'name': 'Fri. 16 Nov. 2012',
#   'day': 16,
#   'month': 11},
#  {'counts': ['7603549', '2630018', '2455217', '0.3228927844'],
#   'year': 2012,
#   'name': 'Sat. 17 Nov. 2012',
#   'day': 17,
#   'month': 11},
#  {'counts': ['7563224', '2610474', '2436847', '0.3265530781'],
#   'year': 2012,
#   'name': 'Sun. 18 Nov. 2012',
#   'day': 18,
#   'month': 11},
#  {'counts': ['7682234', '2694660', '2527283', '0.3297655254'],
#   'year': 2012,
#   'name': 'Mon. 19 Nov. 2012',
#   'day': 19,
#   'month': 11},
#  {'counts': ['7699625', '2704649', '2536194', '0.3352544419'],
#   'year': 2012,
#   'name': 'Tue. 20 Nov. 2012',
#   'day': 20,
#   'month': 11},
#  {'counts': ['7529964', '2626750', '2461546', '0.3326937799'],
#   'year': 2012,
#   'name': 'Wed. 21 Nov. 2012',
#   'day': 21,
#   'month': 11},
#  {'counts': ['7414058', '2571692', '2407227', '0.329467178'],
#   'year': 2012,
#   'name': 'Thu. 22 Nov. 2012',
#   'day': 22,
#   'month': 11},
#  {'counts': ['7582066', '2637847', '2462617', '0.329881732'],
#   'year': 2012,
#   'name': 'Fri. 23 Nov. 2012',
#   'day': 23,
#   'month': 11},
#  {'counts': ['7658847', '2639229', '2458402', '0.3298071119'],
#   'year': 2012,
#   'name': 'Sat. 24 Nov. 2012',
#   'day': 24,
#   'month': 11},
#  {'counts': ['7485471', '2581022', '2409867', '0.3313973416'],
#   'year': 2012,
#   'name': 'Sun. 25 Nov. 2012',
#   'day': 25,
#   'month': 11},
#  {'counts': ['7601938', '2673458', '2505724', '0.3362232215'],
#   'year': 2012,
#   'name': 'Mon. 26 Nov. 2012',
#   'day': 26,
#   'month': 11},
#  {'counts': ['7778570', '2731987', '2559750', '0.3382073503'],
#   'year': 2012,
#   'name': 'Tue. 27 Nov. 2012',
#   'day': 27,
#   'month': 11},
#  {'counts': ['7765405', '2733106', '2561494', '0.3333924702'],
#   'year': 2012,
#   'name': 'Wed. 28 Nov. 2012',
#   'day': 28,
#   'month': 11},
#  {'counts': ['7283895', '2561777', '2402732', '0.333822191'],
#   'year': 2012,
#   'name': 'Thu. 29 Nov. 2012',
#   'day': 29,
#   'month': 11},
#  {'counts': ['6054257', '2142805', '2010234', '0.335548794'],
#   'year': 2012,
#   'name': 'Fri. 30 Nov. 2012',
#   'day': 30,
#   'month': 11},
#  {'counts': ['6333615', '2206657', '2057337', '0.3229813354'],
#   'year': 2012,
#   'name': 'Sat.  1 Dec. 2012',
#   'day': 1,
#   'month': 12},
#  {'counts': ['6379996', '2223778', '2071364', '0.3268142556'],
#   'year': 2012,
#   'name': 'Sun.  2 Dec. 2012',
#   'day': 2,
#   'month': 12},
#  {'counts': ['6374258', '2256982', '2109066', '0.3307144283'],
#   'year': 2012,
#   'name': 'Mon.  3 Dec. 2012',
#   'day': 3,
#   'month': 12},
#  {'counts': ['6428379', '2277106', '2127392', '0.3325962699'],
#   'year': 2012,
#   'name': 'Tue.  4 Dec. 2012',
#   'day': 4,
#   'month': 12},
#  {'counts': ['6693743', '2371680', '2225250', '0.3401268052'],
#   'year': 2012,
#   'name': 'Wed.  5 Dec. 2012',
#   'day': 5,
#   'month': 12},
#  {'counts': ['7614680', '2690430', '2522243', '0.3413948777'],
#   'year': 2012,
#   'name': 'Thu.  6 Dec. 2012',
#   'day': 6,
#   'month': 12},
#  {'counts': ['7462077', '2635160', '2466789', '0.3385880953'],
#   'year': 2012,
#   'name': 'Fri.  7 Dec. 2012',
#   'day': 7,
#   'month': 12},
#  {'counts': ['7487850', '2616125', '2439606', '0.3380422898'],
#   'year': 2012,
#   'name': 'Sat.  8 Dec. 2012',
#   'day': 8,
#   'month': 12},
#  {'counts': ['7509742', '2616324', '2441807', '0.337211916'],
#   'year': 2012,
#   'name': 'Sun.  9 Dec. 2012',
#   'day': 9,
#   'month': 12},
#  {'counts': ['7662805', '2702083', '2531837', '0.3381029953'],
#   'year': 2012,
#   'name': 'Mon. 10 Dec. 2012',
#   'day': 10,
#   'month': 12},
#  {'counts': ['7836581', '2764551', '2587467', '0.3297718616'],
#   'year': 2012,
#   'name': 'Tue. 11 Dec. 2012',
#   'day': 11,
#   'month': 12},
#  {'counts': ['7584336', '2685806', '2515673', '0.3314312826'],
#   'year': 2012,
#   'name': 'Wed. 12 Dec. 2012',
#   'day': 12,
#   'month': 12},
#  {'counts': ['7609017', '2693468', '2520979', '0.3271145314'],
#   'year': 2012,
#   'name': 'Thu. 13 Dec. 2012',
#   'day': 13,
#   'month': 12},
#  {'counts': ['7401174', '2635784', '2468690', '0.3228767674'],
#   'year': 2012,
#   'name': 'Fri. 14 Dec. 2012',
#   'day': 14,
#   'month': 12},
#  {'counts': ['7361381', '2597983', '2421506', '0.3313566936'],
#   'year': 2012,
#   'name': 'Sat. 15 Dec. 2012',
#   'day': 15,
#   'month': 12},
#  {'counts': ['7408728', '2582240', '2408371', '0.3243481995'],
#   'year': 2012,
#   'name': 'Sun. 16 Dec. 2012',
#   'day': 16,
#   'month': 12},
#  {'counts': ['7419845', '2639862', '2472387', '0.3363776876'],
#   'year': 2012,
#   'name': 'Mon. 17 Dec. 2012',
#   'day': 17,
#   'month': 12},
#  {'counts': ['7503832', '2656825', '2487976', '0.3354978044'],
#   'year': 2012,
#   'name': 'Tue. 18 Dec. 2012',
#   'day': 18,
#   'month': 12},
#  {'counts': ['7666156', '2708749', '2532652', '0.3288692501'],
#   'year': 2012,
#   'name': 'Wed. 19 Dec. 2012',
#   'day': 19,
#   'month': 12},
#  {'counts': ['7322329', '2597652', '2428727', '0.3310172793'],
#   'year': 2012,
#   'name': 'Thu. 20 Dec. 2012',
#   'day': 20,
#   'month': 12},
#  {'counts': ['7365253', '2626077', '2454864', '0.3290302546'],
#   'year': 2012,
#   'name': 'Fri. 21 Dec. 2012',
#   'day': 21,
#   'month': 12},
#  {'counts': ['7497466', '2639003', '2458340', '0.3304187196'],
#   'year': 2012,
#   'name': 'Sat. 22 Dec. 2012',
#   'day': 22,
#   'month': 12},
#  {'counts': ['7451524', '2612437', '2431134', '0.3280908028'],
#   'year': 2012,
#   'name': 'Sun. 23 Dec. 2012',
#   'day': 23,
#   'month': 12},
#  {'counts': ['6765727', '2387543', '2221042', '0.33928456'],
#   'year': 2012,
#   'name': 'Mon. 24 Dec. 2012',
#   'day': 24,
#   'month': 12},
#  {'counts': ['7687197', '2684106', '2493294', '0.3315217066'],
#   'year': 2012,
#   'name': 'Tue. 25 Dec. 2012',
#   'day': 25,
#   'month': 12},
#  {'counts': ['8046517', '2811791', '2620263', '0.338511262'],
#   'year': 2012,
#   'name': 'Wed. 26 Dec. 2012',
#   'day': 26,
#   'month': 12},
#  {'counts': ['8053637', '2825761', '2632253', '0.3416052395'],
#   'year': 2012,
#   'name': 'Thu. 27 Dec. 2012',
#   'day': 27,
#   'month': 12},
#  {'counts': ['7788675', '2747372', '2559227', '0.3416415005'],
#   'year': 2012,
#   'name': 'Fri. 28 Dec. 2012',
#   'day': 28,
#   'month': 12},
#  {'counts': ['7708163', '2678163', '2489014', '0.3403590378'],
#   'year': 2012,
#   'name': 'Sat. 29 Dec. 2012',
#   'day': 29,
#   'month': 12},
#  {'counts': ['7436872', '2584107', '2401807', '0.3389405386'],
#   'year': 2012,
#   'name': 'Sun. 30 Dec. 2012',
#   'day': 30,
#   'month': 12},
#  {'counts': ['6676026', '2334501', '2175323', '0.3399443132'],
#   'year': 2012,
#   'name': 'Mon. 31 Dec. 2012',
#   'day': 31,
#   'month': 12},
#  {'counts': ['7091545', '2410659', '2245653', '0.3329567363'],
#   'year': 2013,
#   'name': 'Tue.  1 Jan. 2013',
#   'day': 1,
#   'month': 1},
#  {'counts': ['7964268', '2785835', '2603808', '0.3373843654'],
#   'year': 2013,
#   'name': 'Wed.  2 Jan. 2013',
#   'day': 2,
#   'month': 1},
#  {'counts': ['7935624', '2801263', '2620139', '0.3371885032'],
#   'year': 2013,
#   'name': 'Thu.  3 Jan. 2013',
#   'day': 3,
#   'month': 1},
#  {'counts': ['7819350', '2738888', '2562202', '0.3355324206'],
#   'year': 2013,
#   'name': 'Fri.  4 Jan. 2013',
#   'day': 4,
#   'month': 1},
#  {'counts': ['7794211', '2693580', '2512473', '0.3327895'],
#   'year': 2013,
#   'name': 'Sat.  5 Jan. 2013',
#   'day': 5,
#   'month': 1},
#  {'counts': ['7628850', '2627664', '2452082', '0.3342247192'],
#   'year': 2013,
#   'name': 'Sun.  6 Jan. 2013',
#   'day': 6,
#   'month': 1},
#  {'counts': ['7788205', '2820656', '2646692', '0.3644258244'],
#   'year': 2013,
#   'name': 'Mon.  7 Jan. 2013',
#   'day': 7,
#   'month': 1},
#  {'counts': ['7863299', '2846128', '2671593', '0.3645259742'],
#   'year': 2013,
#   'name': 'Tue.  8 Jan. 2013',
#   'day': 8,
#   'month': 1},
#  {'counts': ['7917795', '2839425', '2662918', '0.3552715323'],
#   'year': 2013,
#   'name': 'Wed.  9 Jan. 2013',
#   'day': 9,
#   'month': 1},
#  {'counts': ['7638747', '2702900', '2532882', '0.3442005258'],
#   'year': 2013,
#   'name': 'Thu. 10 Jan. 2013',
#   'day': 10,
#   'month': 1},
#  {'counts': ['7625444', '2704751', '2534290', '0.3408019553'],
#   'year': 2013,
#   'name': 'Fri. 11 Jan. 2013',
#   'day': 11,
#   'month': 1},
#  {'counts': ['7829910', '2743694', '2559502', '0.3388842622'],
#   'year': 2013,
#   'name': 'Sat. 12 Jan. 2013',
#   'day': 12,
#   'month': 1},
#  {'counts': ['7749048', '2708168', '2527423', '0.3395988125'],
#   'year': 2013,
#   'name': 'Sun. 13 Jan. 2013',
#   'day': 13,
#   'month': 1},
#  {'counts': ['7713439', '2733342', '2560979', '0.3426047644'],
#   'year': 2013,
#   'name': 'Mon. 14 Jan. 2013',
#   'day': 14,
#   'month': 1},
#  {'counts': ['7633378', '2708825', '2539189', '0.3427393364'],
#   'year': 2013,
#   'name': 'Tue. 15 Jan. 2013',
#   'day': 15,
#   'month': 1},
#  {'counts': ['7650732', '2709627', '2539406', '0.3436247103'],
#   'year': 2013,
#   'name': 'Wed. 16 Jan. 2013',
#   'day': 16,
#   'month': 1},
#  {'counts': ['7593427', '2685747', '2516697', '0.344044299'],
#   'year': 2013,
#   'name': 'Thu. 17 Jan. 2013',
#   'day': 17,
#   'month': 1},
#  {'counts': ['7594997', '2678716', '2507483', '0.3392231447'],
#   'year': 2013,
#   'name': 'Fri. 18 Jan. 2013',
#   'day': 18,
#   'month': 1},
#  {'counts': ['7728035', '2696518', '2513692', '0.3388903006'],
#   'year': 2013,
#   'name': 'Sat. 19 Jan. 2013',
#   'day': 19,
#   'month': 1},
#  {'counts': ['7676136', '2678645', '2497062', '0.3425494205'],
#   'year': 2013,
#   'name': 'Sun. 20 Jan. 2013',
#   'day': 20,
#   'month': 1},
#  {'counts': ['8247218', '2930065', '2731055', '0.3476802482'],
#   'year': 2013,
#   'name': 'Mon. 21 Jan. 2013',
#   'day': 21,
#   'month': 1},
#  {'counts': ['8141786', '2911950', '2718000', '0.3474320709'],
#   'year': 2013,
#   'name': 'Tue. 22 Jan. 2013',
#   'day': 22,
#   'month': 1},
#  {'counts': ['7921750', '2841364', '2658146', '0.3470310538'],
#   'year': 2013,
#   'name': 'Wed. 23 Jan. 2013',
#   'day': 23,
#   'month': 1},
#  {'counts': ['7860833', '2790033', '2618540', '0.3335705218'],
#   'year': 2013,
#   'name': 'Thu. 24 Jan. 2013',
#   'day': 24,
#   'month': 1},
#  {'counts': ['7701019', '2740584', '2568741', '0.3371715425'],
#   'year': 2013,
#   'name': 'Fri. 25 Jan. 2013',
#   'day': 25,
#   'month': 1},
#  {'counts': ['7835167', '2738993', '2555809', '0.33724638'],
#   'year': 2013,
#   'name': 'Sat. 26 Jan. 2013',
#   'day': 26,
#   'month': 1},
#  {'counts': ['7909929', '2752581', '2569532', '0.3362958805'],
#   'year': 2013,
#   'name': 'Sun. 27 Jan. 2013',
#   'day': 27,
#   'month': 1},
#  {'counts': ['8190171', '2912120', '2736134', '0.3302411701'],
#   'year': 2013,
#   'name': 'Mon. 28 Jan. 2013',
#   'day': 28,
#   'month': 1},
#  {'counts': ['8138658', '2897548', '2720615', '0.3382964747'],
#   'year': 2013,
#   'name': 'Tue. 29 Jan. 2013',
#   'day': 29,
#   'month': 1},
#  {'counts': ['8196517', '2923435', '2743886', '0.3375568516'],
#   'year': 2013,
#   'name': 'Wed. 30 Jan. 2013',
#   'day': 30,
#   'month': 1},
#  {'counts': ['8397691', '3006479', '2818840', '0.3341360818'],
#   'year': 2013,
#   'name': 'Thu. 31 Jan. 2013',
#   'day': 31,
#   'month': 1},
#  {'counts': ['7938563', '2815639', '2637344', '0.33034447'],
#   'year': 2013,
#   'name': 'Fri.  1 Feb. 2013',
#   'day': 1,
#   'month': 2},
#  {'counts': ['8016804', '2826303', '2637645', '0.3320870549'],
#   'year': 2013,
#   'name': 'Sat.  2 Feb. 2013',
#   'day': 2,
#   'month': 2},
#  {'counts': ['7738891', '2721348', '2540832', '0.3312633767'],
#   'year': 2013,
#   'name': 'Sun.  3 Feb. 2013',
#   'day': 3,
#   'month': 2},
#  {'counts': ['7909335', '2832087', '2658246', '0.3394474581'],
#   'year': 2013,
#   'name': 'Mon.  4 Feb. 2013',
#   'day': 4,
#   'month': 2},
#  {'counts': ['7787148', '2781998', '2609346', '0.3394169086'],
#   'year': 2013,
#   'name': 'Tue.  5 Feb. 2013',
#   'day': 5,
#   'month': 2},
#  {'counts': ['7870941', '2810051', '2634464', '0.342991654'],
#   'year': 2013,
#   'name': 'Wed.  6 Feb. 2013',
#   'day': 6,
#   'month': 2},
#  {'counts': ['7713475', '2754495', '2584758', '0.3393015798'],
#   'year': 2013,
#   'name': 'Thu.  7 Feb. 2013',
#   'day': 7,
#   'month': 2},
#  {'counts': ['7933791', '2826871', '2644392', '0.3323416828'],
#   'year': 2013,
#   'name': 'Fri.  8 Feb. 2013',
#   'day': 8,
#   'month': 2},
# ...
#   'year': 2013,
#   'name': 'Sat.  7 Sep. 2013',
#   'day': 7,
#   'month': 9},
#  {'counts': ['6606952', '2451233', '2299892', '0.3247356454'],
#   'year': 2013,
#   'name': 'Sun.  8 Sep. 2013',
#   'day': 8,
#   'month': 9},
#  {'counts': ['6766375', '2541736', '2393393', '0.328083006'],
#   'year': 2013,
#   'name': 'Mon.  9 Sep. 2013',
#   'day': 9,
#   'month': 9},
#  {'counts': ['6731760', '2531468', '2382082', '0.3282399892'],
#   'year': 2013,
#   'name': 'Tue. 10 Sep. 2013',
#   'day': 10,
#   'month': 9},
#  {'counts': ['6824852', '2559085', '2408184', '0.3227850107'],
#   'year': 2013,
#   'name': 'Wed. 11 Sep. 2013',
#   'day': 11,
#   'month': 9},
#  {'counts': ['6787494', '2556531', '2405600', '0.32436078'],
#   'year': 2013,
#   'name': 'Thu. 12 Sep. 2013',
#   'day': 12,
#   'month': 9},
#  {'counts': ['6690381', '2513937', '2364793', '0.3205141892'],
#   'year': 2013,
#   'name': 'Fri. 13 Sep. 2013',
#   'day': 13,
#   'month': 9},
#  {'counts': ['6492402', '2411626', '2260105', '0.3154443895'],
#   'year': 2013,
#   'name': 'Sat. 14 Sep. 2013',
#   'day': 14,
#   'month': 9},
#  {'counts': ['6517251', '2410584', '2259915', '0.3186592826'],
#   'year': 2013,
#   'name': 'Sun. 15 Sep. 2013',
#   'day': 15,
#   'month': 9},
#  {'counts': ['6598486', '2488486', '2340774', '0.32669797'],
#   'year': 2013,
#   'name': 'Mon. 16 Sep. 2013',
#   'day': 16,
#   'month': 9},
#  {'counts': ['6639240', '2503687', '2356434', '0.3241562799'],
#   'year': 2013,
#   'name': 'Tue. 17 Sep. 2013',
#   'day': 17,
#   'month': 9},
#  {'counts': ['6796364', '2558900', '2408041', '0.3170098704'],
#   'year': 2013,
#   'name': 'Wed. 18 Sep. 2013',
#   'day': 18,
#   'month': 9},
#  {'counts': ['7474921', '2780864', '2616815', '0.3033646923'],
#   'year': 2013,
#   'name': 'Thu. 19 Sep. 2013',
#   'day': 19,
#   'month': 9},
#  {'counts': ['7188828', '2682437', '2522530', '0.3023090493'],
#   'year': 2013,
#   'name': 'Fri. 20 Sep. 2013',
#   'day': 20,
#   'month': 9},
#  {'counts': ['7046927', '2605564', '2441930', '0.3034885808'],
#   'year': 2013,
#   'name': 'Sat. 21 Sep. 2013',
#   'day': 21,
#   'month': 9},
#  {'counts': ['7007860', '2586723', '2425303', '0.3057093027'],
#   'year': 2013,
#   'name': 'Sun. 22 Sep. 2013',
#   'day': 22,
#   'month': 9},
#  {'counts': ['7027070', '2643253', '2486942', '0.3151158076'],
#   'year': 2013,
#   'name': 'Mon. 23 Sep. 2013',
#   'day': 23,
#   'month': 9},
#  {'counts': ['6905407', '2610241', '2457743', '0.3192007894'],
#   'year': 2013,
#   'name': 'Tue. 24 Sep. 2013',
#   'day': 24,
#   'month': 9},
#  {'counts': ['7083647', '2677981', '2523378', '0.3271563616'],
#   'year': 2013,
#   'name': 'Wed. 25 Sep. 2013',
#   'day': 25,
#   'month': 9},
#  {'counts': ['6929015', '2612360', '2463776', '0.3557563037'],
#   'year': 2013,
#   'name': 'Thu. 26 Sep. 2013',
#   'day': 26,
#   'month': 9},
#  {'counts': ['6432988', '2413902', '2272811', '0.3520022041'],
#   'year': 2013,
#   'name': 'Fri. 27 Sep. 2013',
#   'day': 27,
#   'month': 9},
#  {'counts': ['6202216', '2320965', '2177058', '0.3560149955'],
#   'year': 2013,
#   'name': 'Sat. 28 Sep. 2013',
#   'day': 28,
#   'month': 9},
#  {'counts': ['6154148', '2297792', '2156053', '0.3596499754'],
#   'year': 2013,
#   'name': 'Sun. 29 Sep. 2013',
#   'day': 29,
#   'month': 9},
#  {'counts': ['6230659', '2374289', '2235726', '0.3656511179'],
#   'year': 2013,
#   'name': 'Mon. 30 Sep. 2013',
#   'day': 30,
#   'month': 9},
#  {'counts': ['6546956', '2444696', '2300632', '0.3548052233'],
#   'year': 2013,
#   'name': 'Tue.  1 Oct. 2013',
#   'day': 1,
#   'month': 10},
#  {'counts': ['6667735', '2485521', '2337583', '0.354334497'],
#   'year': 2013,
#   'name': 'Wed.  2 Oct. 2013',
#   'day': 2,
#   'month': 10},
#  {'counts': ['6399097', '2417021', '2275587', '0.3648280934'],
#   'year': 2013,
#   'name': 'Thu.  3 Oct. 2013',
#   'day': 3,
#   'month': 10},
#  {'counts': ['6268505', '2374294', '2234729', '0.3600807492'],
#   'year': 2013,
#   'name': 'Fri.  4 Oct. 2013',
#   'day': 4,
#   'month': 10},
#  {'counts': ['6166819', '2296462', '2153569', '0.3591627188'],
#   'year': 2013,
#   'name': 'Sat.  5 Oct. 2013',
#   'day': 5,
#   'month': 10},
#  {'counts': ['6160695', '2306593', '2163591', '0.3646074777'],
#   'year': 2013,
#   'name': 'Sun.  6 Oct. 2013',
#   'day': 6,
#   'month': 10},
#  {'counts': ['6281428', '2390275', '2251916', '0.3710794846'],
#   'year': 2013,
#   'name': 'Mon.  7 Oct. 2013',
#   'day': 7,
#   'month': 10},
#  {'counts': ['6582477', '2480595', '2334008', '0.3644646566'],
#   'year': 2013,
#   'name': 'Tue.  8 Oct. 2013',
#   'day': 8,
#   'month': 10},
#  {'counts': ['6521947', '2477603', '2332257', '0.3624175777'],
#   'year': 2013,
#   'name': 'Wed.  9 Oct. 2013',
#   'day': 9,
#   'month': 10},
#  {'counts': ['6292933', '2402139', '2261989', '0.3636949229'],
#   'year': 2013,
#   'name': 'Thu. 10 Oct. 2013',
#   'day': 10,
#   'month': 10},
#  {'counts': ['6065707', '2328245', '2189530', '0.3696446453'],
#   'year': 2013,
#   'name': 'Fri. 11 Oct. 2013',
#   'day': 11,
#   'month': 10},
#  {'counts': ['6094185', '2323100', '2177294', '0.3633443785'],
#   'year': 2013,
#   'name': 'Sat. 12 Oct. 2013',
#   'day': 12,
#   'month': 10},
#  {'counts': ['6062171', '2299563', '2155504', '0.3697308253'],
#   'year': 2013,
#   'name': 'Sun. 13 Oct. 2013',
#   'day': 13,
#   'month': 10},
#  {'counts': ['6100695', '2354625', '2212973', '0.3766767947'],
#   'year': 2013,
#   'name': 'Mon. 14 Oct. 2013',
#   'day': 14,
#   'month': 10},
#  {'counts': ['6134436', '2357752', '2218493', '0.3733424119'],
#   'year': 2013,
#   'name': 'Tue. 15 Oct. 2013',
#   'day': 15,
#   'month': 10},
#  {'counts': ['6669924', '2502207', '2355054', '0.3600661673'],
#   'year': 2013,
#   'name': 'Wed. 16 Oct. 2013',
#   'day': 16,
#   'month': 10},
#  {'counts': ['7893155', '2848996', '2681620', '0.3345758343'],
#   'year': 2013,
#   'name': 'Thu. 17 Oct. 2013',
#   'day': 17,
#   'month': 10},
#  {'counts': ['7493849', '2670963', '2511683', '0.3410654966'],
#   'year': 2013,
#   'name': 'Fri. 18 Oct. 2013',
#   'day': 18,
#   'month': 10},
#  {'counts': ['7207502', '2567552', '2407624', '0.341986901'],
#   'year': 2013,
#   'name': 'Sat. 19 Oct. 2013',
#   'day': 19,
#   'month': 10},
#  {'counts': ['7180876', '2556040', '2398221', '0.3424738043'],
#   'year': 2013,
#   'name': 'Sun. 20 Oct. 2013',
#   'day': 20,
#   'month': 10},
#  {'counts': ['7460000', '2699311', '2539732', '0.3485280511'],
#   'year': 2013,
#   'name': 'Mon. 21 Oct. 2013',
#   'day': 21,
#   'month': 10},
#  {'counts': ['7281094', '2647106', '2491350', '0.35413904'],
#   'year': 2013,
#   'name': 'Tue. 22 Oct. 2013',
#   'day': 22,
#   'month': 10},
#  {'counts': ['7179190', '2598700', '2445763', '0.3550564906'],
#   'year': 2013,
#   'name': 'Wed. 23 Oct. 2013',
#   'day': 23,
#   'month': 10},
#  {'counts': ['7229263', '2590842', '2439947', '0.3515943134'],
#   'year': 2013,
#   'name': 'Thu. 24 Oct. 2013',
#   'day': 24,
#   'month': 10},
#  {'counts': ['7053819', '2521043', '2373563', '0.3471924618'],
#   'year': 2013,
#   'name': 'Fri. 25 Oct. 2013',
#   'day': 25,
#   'month': 10},
#  {'counts': ['6905246', '2445287', '2293702', '0.3459793765'],
#   'year': 2013,
#   'name': 'Sat. 26 Oct. 2013',
#   'day': 26,
#   'month': 10},
#  {'counts': ['7051944', '2490673', '2336234', '0.3461354586'],
#   'year': 2013,
#   'name': 'Sun. 27 Oct. 2013',
#   'day': 27,
#   'month': 10},
#  {'counts': ['7234844', '2629877', '2477602', '0.35447639'],
#   'year': 2013,
#   'name': 'Mon. 28 Oct. 2013',
#   'day': 28,
#   'month': 10},
#  {'counts': ['7271847', '2669285', '2514528', '0.3548506426'],
#   'year': 2013,
#   'name': 'Tue. 29 Oct. 2013',
#   'day': 29,
#   'month': 10},
#  {'counts': ['7255222', '2618337', '2466117', '0.3526759059'],
#   'year': 2013,
#   'name': 'Wed. 30 Oct. 2013',
#   'day': 30,
#   'month': 10},
#  {'counts': ['6767188', '2446048', '2304000', '0.3556406567'],
#   'year': 2013,
#   'name': 'Thu. 31 Oct. 2013',
#   'day': 31,
#   'month': 10},
#  {'counts': ['6756389', '2421294', '2279686', '0.3522195389'],
#   'year': 2013,
#   'name': 'Fri.  1 Nov. 2013',
#   'day': 1,
#   'month': 11},
#  {'counts': ['6485102', '2308671', '2169485', '0.3483858849'],
#   'year': 2013,
#   'name': 'Sat.  2 Nov. 2013',
#   'day': 2,
#   'month': 11},
#  {'counts': ['6708890', '2381785', '2238764', '0.3491548114'],
#   'year': 2013,
#   'name': 'Sun.  3 Nov. 2013',
#   'day': 3,
#   'month': 11},
#  {'counts': ['7043764', '2545239', '2406290', '0.3423934318'],
#   'year': 2013,
#   'name': 'Mon.  4 Nov. 2013',
#   'day': 4,
#   'month': 11},
#  {'counts': ['6963136', '2505876', '2365903', '0.3419813347'],
#   'year': 2013,
#   'name': 'Tue.  5 Nov. 2013',
#   'day': 5,
#   'month': 11},
#  {'counts': ['6834764', '2460706', '2321041', '0.3482918732'],
#   'year': 2013,
#   'name': 'Wed.  6 Nov. 2013',
#   'day': 6,
#   'month': 11},
#  {'counts': ['6779846', '2482399', '2338444', '0.3573611376'],
#   'year': 2013,
#   'name': 'Thu.  7 Nov. 2013',
#   'day': 7,
#   'month': 11},
#  {'counts': ['6444950', '2294680', '2162927', '0.344578207'],
#   'year': 2013,
#   'name': 'Fri.  8 Nov. 2013',
#   'day': 8,
#   'month': 11},
#  {'counts': ['6350122', '2252700', '2116132', '0.3453863545'],
#   'year': 2013,
#   'name': 'Sat.  9 Nov. 2013',
#   'day': 9,
#   'month': 11},
#  {'counts': ['6226597', '2231957', '2100195', '0.350147722'],
#   'year': 2013,
#   'name': 'Sun. 10 Nov. 2013',
#   'day': 10,
#   'month': 11},
#  {'counts': ['6539947', '2331617', '2198954', '0.3508372012'],
#   'year': 2013,
#   'name': 'Mon. 11 Nov. 2013',
#   'day': 11,
#   'month': 11},
#  {'counts': ['6578833', '2357679', '2223952', '0.3523311065'],
#   'year': 2013,
#   'name': 'Tue. 12 Nov. 2013',
#   'day': 12,
#   'month': 11},
#  {'counts': ['6592679', '2358884', '2223926', '0.3508961512'],
#   'year': 2013,
#   'name': 'Wed. 13 Nov. 2013',
#   'day': 13,
#   'month': 11},
#  {'counts': ['6614595', '2367183', '2230115', '0.3486348966'],
#   'year': 2013,
#   'name': 'Thu. 14 Nov. 2013',
#   'day': 14,
#   'month': 11},
#  {'counts': ['6341212', '2288998', '2157664', '0.3488806982'],
#   'year': 2013,
#   'name': 'Fri. 15 Nov. 2013',
#   'day': 15,
#   'month': 11},
#  {'counts': ['6419695', '2296229', '2157840', '0.3449022205'],
#   'year': 2013,
#   'name': 'Sat. 16 Nov. 2013',
#   'day': 16,
#   'month': 11},
#  {'counts': ['6427164', '2296866', '2160130', '0.3486058252'],
#   'year': 2013,
#   'name': 'Sun. 17 Nov. 2013',
#   'day': 17,
#   'month': 11},
#  {'counts': ['6245267', '2271659', '2145749', '0.3589135636'],
#   'year': 2013,
#   'name': 'Mon. 18 Nov. 2013',
#   'day': 18,
#   'month': 11},
#  {'counts': ['6436675', '2334580', '2204683', '0.3522804931'],
#   'year': 2013,
#   'name': 'Tue. 19 Nov. 2013',
#   'day': 19,
#   'month': 11},
#  {'counts': ['6395172', '2373365', '2243394', '0.3504716063'],
#   'year': 2013,
#   'name': 'Wed. 20 Nov. 2013',
#   'day': 20,
#   'month': 11},
#  {'counts': ['6270684', '2329253', '2201367', '0.348709355'],
#   'year': 2013,
#   'name': 'Thu. 21 Nov. 2013',
#   'day': 21,
#   'month': 11},
#  {'counts': ['6136617', '2293757', '2164601', '0.3445988311'],
#   'year': 2013,
#   'name': 'Fri. 22 Nov. 2013',
#   'day': 22,
#   'month': 11},
#  {'counts': ['6143325', '2243553', '2110810', '0.340078602'],
#   'year': 2013,
#   'name': 'Sat. 23 Nov. 2013',
#   'day': 23,
#   'month': 11},
#  {'counts': ['6078052', '2224926', '2095659', '0.3439138194'],
#   'year': 2013,
#   'name': 'Sun. 24 Nov. 2013',
#   'day': 24,
#   'month': 11},
#  {'counts': ['6491124', '2436725', '2301992', '0.3403119026'],
#   'year': 2013,
#   'name': 'Mon. 25 Nov. 2013',
#   'day': 25,
#   'month': 11},
#  {'counts': ['6497860', '2442011', '2306607', '0.3429875154'],
#   'year': 2013,
#   'name': 'Tue. 26 Nov. 2013',
#   'day': 26,
#   'month': 11},
#  {'counts': ['6564515', '2463662', '2329853', '0.3427913115'],
#   'year': 2013,
#   'name': 'Wed. 27 Nov. 2013',
#   'day': 27,
#   'month': 11},
#  {'counts': ['6209372', '2326077', '2196559', '0.3458635446'],
#   'year': 2013,
#   'name': 'Thu. 28 Nov. 2013',
#   'day': 28,
#   'month': 11},
#  {'counts': ['6220282', '2311837', '2178513', '0.3495818728'],
#   'year': 2013,
#   'name': 'Fri. 29 Nov. 2013',
#   'day': 29,
#   'month': 11},
#  {'counts': ['6207851', '2289269', '2152306', '0.34676269'],
#   'year': 2013,
#   'name': 'Sat. 30 Nov. 2013',
#   'day': 30,
#   'month': 11},
#  {'counts': ['6202120', '2284696', '2150198', '0.3500549133'],
#   'year': 2013,
#   'name': 'Sun.  1 Dec. 2013',
#   'day': 1,
#   'month': 12},
#  {'counts': ['6234554', '2343941', '2214093', '0.360339004'],
#   'year': 2013,
#   'name': 'Mon.  2 Dec. 2013',
#   'day': 2,
#   'month': 12},
#  {'counts': ['6265101', '2359284', '2229496', '0.3615460279'],
#   'year': 2013,
#   'name': 'Tue.  3 Dec. 2013',
#   'day': 3,
#   'month': 12},
#  {'counts': ['6868631', '2605502', '2453625', '0.3408088811'],
#   'year': 2013,
#   'name': 'Wed.  4 Dec. 2013',
#   'day': 4,
#   'month': 12},
#  {'counts': ['6315869', '2397463', '2263122', '0.3535183682'],
#   'year': 2013,
#   'name': 'Thu.  5 Dec. 2013',
#   'day': 5,
#   'month': 12},
#  {'counts': ['6149896', '2341784', '2210115', '0.35182905'],
#   'year': 2013,
#   'name': 'Fri.  6 Dec. 2013',
#   'day': 6,
#   'month': 12},
#  {'counts': ['6167949', '2319202', '2181913', '0.3480923468'],
#   'year': 2013,
#   'name': 'Sat.  7 Dec. 2013',
#   'day': 7,
#   'month': 12},
#  {'counts': ['6085308', '2290290', '2157527', '0.3514078618'],
#   'year': 2013,
#   'name': 'Sun.  8 Dec. 2013',
#   'day': 8,
#   'month': 12},
#  {'counts': ['6199619', '2363969', '2234486', '0.3590498303'],
#   'year': 2013,
#   'name': 'Mon.  9 Dec. 2013',
#   'day': 9,
#   'month': 12},
#  {'counts': ['6195343', '2356600', '2227891', '0.3595607281'],
#   'year': 2013,
#   'name': 'Tue. 10 Dec. 2013',
#   'day': 10,
#   'month': 12},
#  {'counts': ['6466093', '2448160', '2311896', '0.3542515314'],
#   'year': 2013,
#   'name': 'Wed. 11 Dec. 2013',
#   'day': 11,
#   'month': 12},
#  {'counts': ['6551910', '2485461', '2346026', '0.3505576985'],
#   'year': 2013,
#   'name': 'Thu. 12 Dec. 2013',
#   'day': 12,
#   'month': 12},
#  {'counts': ['6235409', '2374973', '2242232', '0.3534947455'],
#   'year': 2013,
#   'name': 'Fri. 13 Dec. 2013',
#   'day': 13,
#   'month': 12},
#  {'counts': ['6235421', '2349333', '2208231', '0.3524640555'],
#   'year': 2013,
#   'name': 'Sat. 14 Dec. 2013',
#   'day': 14,
#   'month': 12},
#  {'counts': ['6183534', '2330233', '2193340', '0.3559497026'],
#   'year': 2013,
#   'name': 'Sun. 15 Dec. 2013',
#   'day': 15,
#   'month': 12},
#  {'counts': ['6313852', '2412589', '2278138', '0.361677715'],
#   'year': 2013,
#   'name': 'Mon. 16 Dec. 2013',
#   'day': 16,
#   'month': 12},
#  {'counts': ['6213333', '2372514', '2240116', '0.3614179454'],
#   'year': 2013,
#   'name': 'Tue. 17 Dec. 2013',
#   'day': 17,
#   'month': 12},
#  {'counts': ['6107350', '2328882', '2198126', '0.3606221636'],
#   'year': 2013,
#   'name': 'Wed. 18 Dec. 2013',
#   'day': 18,
#   'month': 12},
#  {'counts': ['5978774', '2289061', '2162484', '0.3614095025'],
#   'year': 2013,
#   'name': 'Thu. 19 Dec. 2013',
#   'day': 19,
#   'month': 12},
#  {'counts': ['5841293', '2220832', '2095095', '0.3568145073'],
#   'year': 2013,
#   'name': 'Fri. 20 Dec. 2013',
#   'day': 20,
#   'month': 12},
#  {'counts': ['5879700', '2208170', '2077379', '0.3534184112'],
#   'year': 2013,
#   'name': 'Sat. 21 Dec. 2013',
#   'day': 21,
#   'month': 12},
#  {'counts': ['5907057', '2229404', '2096856', '0.3549142452'],
#   'year': 2013,
#   'name': 'Sun. 22 Dec. 2013',
#   'day': 22,
#   'month': 12},
#  {'counts': ['6253804', '2382746', '2248016', '0.3508893087'],
#   'year': 2013,
#   'name': 'Mon. 23 Dec. 2013',
#   'day': 23,
#   'month': 12},
#  {'counts': ['5716214', '2159539', '2035913', '0.3493026231'],
#   'year': 2013,
#   'name': 'Tue. 24 Dec. 2013',
#   'day': 24,
#   'month': 12},
#  {'counts': ['6034264', '2268178', '2129772', '0.3529165294'],
#   'year': 2013,
#   'name': 'Wed. 25 Dec. 2013',
#   'day': 25,
#   'month': 12},
#  {'counts': ['6451678', '2444938', '2301998', '0.3605341325'],
#   'year': 2013,
#   'name': 'Thu. 26 Dec. 2013',
#   'day': 26,
#   'month': 12},
#  {'counts': ['6328774', '2395841', '2256768', '0.3595124914'],
#   'year': 2013,
#   'name': 'Fri. 27 Dec. 2013',
#   'day': 27,
#   'month': 12},
#  {'counts': ['6189963', '2333545', '2194440', '0.3647221776'],
#   'year': 2013,
#   'name': 'Sat. 28 Dec. 2013',
#   'day': 28,
#   'month': 12},
#  {'counts': ['6183667', '2313966', '2176780', '0.3597183086'],
#   'year': 2013,
#   'name': 'Sun. 29 Dec. 2013',
#   'day': 29,
#   'month': 12},
#  {'counts': ['6469028', '2441133', '2300662', '0.3605517979'],
#   'year': 2013,
#   'name': 'Mon. 30 Dec. 2013',
#   'day': 30,
#   'month': 12},
#  {'counts': ['5523521', '2069896', '1950572', '0.3597248568'],
#   'year': 2013,
#   'name': 'Tue. 31 Dec. 2013',
#   'day': 31,
#   'month': 12}]

# %%
# list of dicts for report column - metrics row:
km_rm = km_df['report']['metrics']

print(km_rm)

# Create a list of the metric names:
metric_names = [mt_dict['name'].lower().replace(" ", "_") for mt_dict in km_rm]
#print(metric_names)
# Out:
# [{'current': False, 'latency': 0, 'type': 'number', 'id': 'PageViews', 'name': 'Page Views'}, {'current': False, 'latency': 0, 'type': 'number', 'id': 'Visits', 'name': 'Visits'}, {'current': False, 'latency': 0, 'type': 'number', 'id': 'UniqueVisitors', 'name': 'Unique Visitors'}, {'current': False, 'latency': 0, 'type': 'number', 'id': 'BounceRate', 'name': 'Bounce Rate'}]

# %%
# Merge the lists of fdicts for data and metrics:
import datetime as dt
from datetime import datetime, date 

key_metrics_data = []

for rd in km_rd:
    dt_metric_dict = {}
    # Counts per date:
    counts = [float(count) if count.upper() != 'INF' else 0 for count in rd['counts']]
    #print(counts_df)
    #int_counts = list(map(int, rd['counts']))
    #print(int_counts)
    # Zip togther metic names with counts list:
    metric_dict = dict(zip(metric_names, counts))
    #print(metrics)
    # convert to datetime:
    date_str = str(rd['year']) + ' ' +  str(rd['month']) + ' ' + str(rd['day'])
    dt_date = dt.datetime.strptime(date_str, '%Y %m %d').date()
    #print(dt_date)
    dt_metric_dict['date'] = dt_date
    dt_metric_dict.update(metric_dict)
    # print(dt_metric_dict)
    key_metrics_data.append(dt_metric_dict)
    
print(key_metrics_data)

""""
import json
with open('task1_key_metrics.json', 'w') as f:
    f.write(json.dumps(key_metrics_data, default=str))
"""
# Out:
# [{'date': datetime.date(2012, 1, 1), 'page_views': 0.0, 'visits': 0.0, 'unique_visitors': 0.0, 'bounce_rate': 0}, {'date': datetime.date(2012, 1, 2), 'page_views': 0.0, 'visits': 0.0, 'unique_visitors': 0.0, 'bounce_rate': 0}, {'date': datetime.date(2012, 1, 3), 'page_views': 0.0, 'visits': 0.0, 'unique_visitors': 0.0, 'bounce_rate': 0}, {'date': datetime.date(2012, 1, 4), 'page_views': 0.0, 'visits': 0.0, 'unique_visitors': 0.0, 'bounce_rate': 0}, {'date': datetime.date(2012, 1, 5), 'page_views': 0.0, 'visits': 0.0, 'unique_visitors': 0.0, 'bounce_rate': 0}, {'date': datetime.date(2012, 1, 6), 'page_views': 0.0, 'visits': 0.0, 'unique_visitors': 0.0, 'bounce_rate': 0}, {'date': datetime.date(2012, 1, 7), 'page_views': 0.0, 'visits': 0.0, 'unique_visitors': 0.0, 'bounce_rate': 0}, {'date': datetime.date(2012, 1, 8), 'page_views': 0.0, 'visits': 0.0, 'unique_visitors': 0.0, 'bounce_rate': 0}, {'date': datetime.date(2012, 1, 9), 'page_views': 0.0, 'visits': 0.0, 'unique_visitors': 0.0, 'bounce_rate': 0}, {'date': datetime.date(2012, 1, 10), 'page_views': 0.0, 'visits': 0.0, 'unique_visitors': 0.0, 'bounce_rate': 0}, {'date': datetime.date(2012, 1, 11), 'page_views': 0.0, 'visits': 0.0, 'unique_visitors': 0.0, 'bounce_rate': 0}, {'date': datetime.date(2012, 1, 12), 'page_views': 0.0, 'visits': 0.0, 'unique_visitors': 0.0, 'bounce_rate': 0}, {'date': datetime.date(2012, 1, 13), 'page_views': 0.0, 'visits': 0.0, 'unique_visitors': 0.0, 'bounce_rate': 0}, {'date': datetime.date(2012, 1, 14), 'page_views': 0.0, 'visits': 0.0, 'unique_visitors': 0.0, 'bounce_rate': 0}, {'date': datetime.date(2012, 1, 15), 'page_views': 0.0, 'visits': 0.0, 'unique_visitors': 0.0, 'bounce_rate': 0}, {'date': datetime.date(2012, 1, 16), 'page_views': 0.0, 'visits': 0.0, 'unique_visitors': 0.0, 'bounce_rate': 0}, {'date': datetime.date(2012, 1, 17), 'page_views': 0.0, 'visits': 0.0, 'unique_visitors': 0.0, 'bounce_rate': 0}, {'date': datetime.date(2012, 1, 18), 'page_views': 0.0, 'visits': 0.0, 'unique_visitors': 0.0, 'bounce_rate': 0}, {'date': datetime.date(2012, 1, 19), 'page_views': 0.0, 'visits': 0.0, 'unique_visitors': 0.0, 'bounce_rate': 0}, {'date': datetime.date(2012, 1, 20), 'page_views': 0.0, 'visits': 0.0, 'unique_visitors': 0.0, 'bounce_rate': 0}, {'date': datetime.date(2012, 1, 21), 'page_views': 0.0, 'visits': 0.0, 'unique_visitors': 0.0, 'bounce_rate': 0}, {'date': datetime.date(2012, 1, 22), 'page_views': 0.0, 'visits': 0.0, 'unique_visitors': 0.0, 'bounce_rate': 0}, {'date': datetime.date(2012, 1, 23), 'page_views': 0.0, 'visits': 0.0, 'unique_visitors': 0.0, 'bounce_rate': 0}, {'date': datetime.date(2012, 1, 24), 'page_views': 0.0, 'visits': 0.0, 'unique_visitors': 0.0, 'bounce_rate': 0}, {'date': datetime.date(2012, 1, 25), 'page_views': 0.0, 'visits': 0.0, 'unique_visitors': 0.0, 'bounce_rate': 0}, {'date': datetime.date(2012, 1, 26), 'page_views': 0.0, 'visits': 0.0, 'unique_visitors': 0.0, 'bounce_rate': 0}, {'date': datetime.date(2012, 1, 27), 'page_views': 0.0, 'visits': 0.0, 'unique_visitors': 0.0, 'bounce_rate': 0}, {'date': datetime.date(2012, 1, 28), 'page_views': 0.0, 'visits': 0.0, 'unique_visitors': 0.0, 'bounce_rate': 0}, {'date': datetime.date(2012, 1, 29), 'page_views': 0.0, 'visits': 0.0, 'unique_visitors': 0.0, 'bounce_rate': 0}, {'date': datetime.date(2012, 1, 30), 'page_views': 0.0, 'visits': 0.0, 'unique_visitors': 0.0, 'bounce_rate': 0}, {'date': datetime.date(2012, 1, 31), 'page_views': 0.0, 'visits': 0.0, 'unique_visitors': 0.0, 'bounce_rate': 0}, {'date': datetime.date(2012, 2, 1), 'page_views': 0.0, 'visits': 0.0, 'unique_visitors': 0.0, 'bounce_rate': 0}, {'date': datetime.date(2012, 2, 2), 'page_views': 0.0, 'visits': 0.0, 'unique_visitors': 0.0, 'bounce_rate': 0}, {'date': datetime.date(2012, 2, 3), 'page_views': 0.0, 'visits': 0.0, 'unique_visitors': 0.0, 'bounce_rate': 0}, {'date': datetime.date(2012, 2, 4), 'page_views': 0.0, 'visits': 0.0, 'unique_visitors': 0.0, 'bounce_rate': 0}, {'date': datetime.date ...
# '"\nimport json\nwith open(\'task1_key_metrics.json\', \'w\') as f:\n    f.write(json.dumps(key_metrics_data, default=str))\n'
